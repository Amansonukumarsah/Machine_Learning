# %%
print("T20 World Cup Cricket Score Predictor")
# Out:
# T20 World Cup Cricket Score Predictor

# %%
#T20 World Cup Cricket Score Predictor

# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %%
filenames = []
for file in os.listdir('data'):
    filenames.append(os.path.join('data',file))

# %%
filenames = filenames[1:]
# len(filenames)
# filenames[0:1]
filenames[1:4]
# Out:
# ['data\\1019983.yaml', 'data\\1020029.yaml', 'data\\1031431.yaml']

# %%
final_df = []
count=1
for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = count
        final_df.append(df)
        count+=1
df = pd.DataFrame(final_df)
final_df
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉| 2107/2108 [07:50<00:00,  4.48it/s]
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[7], line 5
#       3 for file in tqdm(filenames):
#       4     with open(file, 'r') as f:
# ----> 5         df = pd.json_normalize(safe_load(f))
#       6         df['match_id'] = count
#       7         final_df.append(df)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_normalize.py:445, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     443     data = list(data)
#     444 else:
# --> 445     raise NotImplementedError
#     447 # check to see if a simple recursive function is possible to
#     448 # improve performance (see #15621) but only for cases such
#     449 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
#     450 if (
#     451     record_path is None
#     452     and meta is None
#    (...)
#     455     and max_level is None
#     456 ):
#
# NotImplementedError:

# %%
final_df
# Out:
# [                                             innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'New Zealand', 'deli...               0.91
#
#    meta.created  meta.revision  info.balls_per_over        info.city  \
#  0   2017-01-08              1                    6  Mount Maunganui
#
#       info.dates info.gender info.match_type  info.outcome.by.runs  ...  \
#  0  [2017-01-06]        male             T20                    47  ...
#
#    info.registry.people.TA Boult  info.registry.people.TC Bruce  \
#  0                      a818c1be                       f92c9151
#
#    info.registry.people.Tamim Iqbal info.registry.people.WR Knights  \
#  0                         3b041a12                        63cbf8d8
#
#                    info.teams info.toss.decision info.toss.winner  \
#  0  [New Zealand, Bangladesh]              field       Bangladesh
#
#            info.umpires info.venue match_id
#  0  [CM Brown, SB Haig]   Bay Oval        1
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'New Zealand', 'deli...               0.91
#
#    meta.created  meta.revision  info.balls_per_over        info.city  \
#  0   2017-01-08              2                    6  Mount Maunganui
#
#       info.dates info.gender info.match_type  info.outcome.by.runs  ...  \
#  0  [2017-01-08]        male             T20                    27  ...
#
#    info.registry.people.TC Bruce  info.registry.people.Tamim Iqbal  \
#  0                      f92c9151                          3b041a12
#
#    info.registry.people.Taskin Ahmed info.registry.people.WR Knights  \
#  0                          ef18b66e                        63cbf8d8
#
#                    info.teams info.toss.decision info.toss.winner  \
#  0  [New Zealand, Bangladesh]              field       Bangladesh
#
#               info.umpires info.venue match_id
#  0  [CM Brown, WR Knights]   Bay Oval        2
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'South Africa', 'del...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2017-02-18              1                    6  Auckland  [2017-02-17]
#
#    info.gender info.match_type  info.outcome.by.runs  ...  \
#  0        male             T20                    78  ...
#
#    info.registry.people.TC Bruce  info.registry.people.TG Southee  \
#  0                      f92c9151                         13c35c9e
#
#    info.registry.people.WD Parnell info.registry.people.WR Knights  \
#  0                        3a60e0b5                        63cbf8d8
#
#                      info.teams info.toss.decision info.toss.winner  \
#  0  [New Zealand, South Africa]              field      New Zealand
#
#               info.umpires info.venue match_id
#  0  [CM Brown, WR Knights]  Eden Park        3
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'South Africa', 'del...               0.91
#
#    meta.created  meta.revision  info.balls_per_over    info.city    info.dates  \
#  0   2017-06-24              1                    6  Southampton  [2017-06-21]
#
#    info.gender info.match_type  info.outcome.by.wickets  ...  \
#  0        male             T20                        9  ...
#
#    info.registry.people.RT Robinson  info.registry.people.SW Billings  \
#  0                         b143c87d                          c16d4035
#
#    info.registry.people.T Shamsi info.registry.people.WD Parnell  \
#  0                      a03bba42                        3a60e0b5
#
#                  info.teams info.toss.decision info.toss.winner  \
#  0  [England, South Africa]                bat     South Africa
#
#                 info.umpires     info.venue match_id
#  0  [RJ Bailey, RT Robinson]  The Rose Bowl        4
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'South Africa', 'del...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2017-06-24              1                    6   Taunton  [2017-06-23]
#
#    info.gender info.match_type  info.outcome.by.runs  ...  \
#  0        male             T20                     3  ...
#
#    info.registry.people.RT Robinson  info.registry.people.SW Billings  \
#  0                         b143c87d                          c16d4035
#
#    info.registry.people.T Shamsi info.registry.people.TK Curran  \
#  0                      a03bba42                       e86754b2
#
#                  info.teams info.toss.decision info.toss.winner  \
#  0  [England, South Africa]              field          England
#
#              info.umpires     info.venue match_id
#  0  [RJ Bailey, MA Gough]  County Ground        5
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'New Zealand', 'deli...               0.91
#
#    meta.created  meta.revision  info.balls_per_over    info.dates info.gender  \
#  0   2017-02-23              1                    6  [2017-02-22]      female
#
#    info.match_type  info.outcome.by.runs info.outcome.winner  ...  \
#  0             T20                    47         New Zealand  ...
#
#     info.registry.people.RH Priest info.registry.people.SAJ Craig  \
#  0                        e6f0408a                       689f2eed
#
#    info.registry.people.SR Bernard info.registry.people.SW Bates  \
#  0                        800187dc                      89bbc67a
#
#                   info.teams info.toss.decision info.toss.winner  \
#  0  [Australia, New Zealand]                bat      New Zealand
#
#            info.umpires     info.venue match_id
#  0  [GA Abood, JD Ward]  Adelaide Oval        6
#
#  [1 rows x 47 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Pakistan', 'deliver...               0.91
#
#    meta.created  meta.revision  info.balls_per_over    info.dates info.gender  \
#  0   2016-09-29              1                    6  [2016-09-24]        male
#
#    info.match_type  info.neutral_venue  info.outcome.by.runs  ...  \
#  0             T20                   1                    16  ...
#
#    info.registry.people.Shozab Raza  info.registry.people.Sohail Tanvir  \
#  0                         153c67dc                            64d43928
#
#    info.registry.people.Umar Akmal info.registry.people.Wahab Riaz  \
#  0                        fd2bf2a0                        b3118300
#
#                  info.teams info.toss.decision info.toss.winner  \
#  0  [Pakistan, West Indies]              field      West Indies
#
#                    info.umpires                           info.venue match_id
#  0  [Ahmed Shahab, Shozab Raza]  Dubai International Cricket Stadium        7
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'New Zealand', 'deli...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-07-03              1                    6  Auckland  [2018-02-16]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     649  ...
#
#    info.registry.people.TA Boult  info.registry.people.TG Southee  \
#  0                      a818c1be                         13c35c9e
#
#     info.registry.people.TL Seifert info.registry.people.WR Knights  \
#  0                         4663bd23                        63cbf8d8
#
#                   info.teams info.toss.decision info.toss.winner  \
#  0  [New Zealand, Australia]                bat      New Zealand
#
#            info.umpires info.venue match_id
#  0  [P Wilson, SB Haig]  Eden Park        8
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Scotland', 'deliver...               0.91
#
#    meta.created  meta.revision  info.balls_per_over  info.city    info.dates  \
#  0   2017-01-18              2                    6  Abu Dhabi  [2017-01-14]
#
#    info.gender info.match_type  info.neutral_venue  ...  \
#  0        male             T20                   1  ...
#
#     info.registry.people.Shahid Wasif info.registry.people.Tanveer Ahmed  \
#  0                           2cc08c3c                           571f11e4
#
#     info.registry.people.Waqas Barkat info.registry.people.Waqas Khan  \
#  0                           a2eac9df                        35971419
#
#                info.teams info.toss.decision info.toss.winner  \
#  0  [Hong Kong, Scotland]                bat         Scotland
#
#                       info.umpires            info.venue match_id
#  0  [Ahmed Shah Pakteen, AJ Neill]  Sheikh Zayed Stadium        9
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Hong Kong', 'delive...               0.91
#
#    meta.created  meta.revision  info.balls_per_over  info.city    info.dates  \
#  0   2017-01-18              1                    6  Abu Dhabi  [2017-01-16]
#
#    info.gender info.match_type  info.neutral_venue  ...  \
#  0        male             T20                   1  ...
#
#     info.registry.people.Sultan Ahmed info.registry.people.Tanveer Ahmed  \
#  0                           3bf7c034                           571f11e4
#
#     info.registry.people.Waqas Khan info.registry.people.Zeeshan Maqsood  \
#  0                         35971419                             34464143
#
#            info.teams info.toss.decision info.toss.winner  \
#  0  [Hong Kong, Oman]              field             Oman
#
#                 info.umpires            info.venue match_id
#  0  [Iftikhar Ali, AJ Neill]  Sheikh Zayed Stadium       10
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Scotland', 'deliver...               0.91
#
#    meta.created  meta.revision  info.balls_per_over  info.city    info.dates  \
#  0   2017-01-18              1                    6  Abu Dhabi  [2017-01-17]
#
#    info.gender info.match_type  info.neutral_venue  ...  \
#  0        male             T20                   1  ...
#
#     info.registry.people.T van der Gugten info.registry.people.TP Visee  \
#  0                               d99cc23a                      881b3f8e
#
#     info.registry.people.Tabarak Dar info.registry.people.W Barresi  \
#  0                          2259c12d                       0d677597
#
#                  info.teams info.toss.decision info.toss.winner  \
#  0  [Netherlands, Scotland]              field      Netherlands
#
#                info.umpires            info.venue match_id
#  0  [AJ Neill, Tabarak Dar]  Sheikh Zayed Stadium       11
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Ireland', 'deliveri...               0.91
#
#    meta.created  meta.revision  info.balls_per_over    info.dates info.gender  \
#  0   2017-01-18              2                    6  [2017-01-18]        male
#
#    info.match_type  info.outcome.by.runs info.outcome.winner  ...  \
#  0             T20                    24             Ireland  ...
#
#     info.registry.people.Shaiman Anwar info.registry.people.WB Rankin  \
#  0                            e9630504                       29b89ae8
#
#    info.registry.people.WTS Porterfield info.registry.people.Zahoor Khan  \
#  0                             ec02b798                         f0e293b0
#
#                          info.teams info.toss.decision info.toss.winner  \
#  0  [United Arab Emirates, Ireland]                bat          Ireland
#
#                         info.umpires                           info.venue  \
#  0  [Ahmed Shah Durrani, BB Pradhan]  Dubai International Cricket Stadium
#
#    match_id
#  0       12
#
#  [1 rows x 46 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'England', 'deliveri...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-08-08              1                    6    Sydney  [2017-11-17]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     391  ...
#
#    info.registry.people.SE Aley  info.registry.people.SJ Taylor  \
#  0                     5be043df                        e6f36f83
#
#     info.registry.people.SR Bernard info.registry.people.TT Beaumont  \
#  0                         800187dc                         b2664905
#
#               info.teams info.toss.decision info.toss.winner  \
#  0  [England, Australia]              field        Australia
#
#               info.umpires         info.venue match_id
#  0  [GC Joshua, SAJ Craig]  North Sydney Oval       13
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'England', 'deliveri...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-08-08              1                    6  Canberra  [2017-11-19]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     392  ...
#
#    info.registry.people.SE Aley  info.registry.people.SJ Taylor  \
#  0                     5be043df                        e6f36f83
#
#     info.registry.people.SR Bernard info.registry.people.TT Beaumont  \
#  0                         800187dc                         b2664905
#
#               info.teams info.toss.decision info.toss.winner  \
#  0  [England, Australia]                bat          England
#
#             info.umpires   info.venue match_id
#  0  [JD Ward, GC Joshua]  Manuka Oval       14
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Australia', 'delive...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-08-08              1                    6  Canberra  [2017-11-21]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     393  ...
#
#    info.registry.people.SAJ Craig  info.registry.people.SJ Taylor  \
#  0                       689f2eed                        e6f36f83
#
#     info.registry.people.SR Bernard info.registry.people.TT Beaumont  \
#  0                         800187dc                         b2664905
#
#               info.teams info.toss.decision info.toss.winner  \
#  0  [Australia, England]                bat        Australia
#
#             info.umpires   info.venue match_id
#  0  [JD Ward, SAJ Craig]  Manuka Oval       15
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Papua New Guinea', ...               0.91
#
#    meta.created  meta.revision  info.balls_per_over  info.city    info.dates  \
#  0   2017-04-12              2                    6  Abu Dhabi  [2017-04-12]
#
#    info.gender info.match_type  info.outcome.by.wickets  ...  \
#  0        male             T20                        5  ...
#
#    info.registry.people.Sultan Ahmed (2)  info.registry.people.TP Ura  \
#  0                              07687c15                     a82eb3fb
#
#    info.registry.people.VV Morea info.registry.people.WT Gavera  \
#  0                      e64c10dd                       7516045a
#
#                                   info.teams info.toss.decision  \
#  0  [United Arab Emirates, Papua New Guinea]              field
#
#         info.toss.winner              info.umpires            info.venue  \
#  0  United Arab Emirates  [Akbar Ali, Shozab Raza]  Sheikh Zayed Stadium
#
#    match_id
#  0       16
#
#  [1 rows x 46 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'United Arab Emirate...               0.91
#
#    meta.created  meta.revision  info.balls_per_over  info.city    info.dates  \
#  0   2017-04-14              2                    6  Abu Dhabi  [2017-04-14]
#
#    info.gender info.match_type  info.outcome.by.runs  ...  \
#  0        male             T20                    30  ...
#
#    info.registry.people.Shozab Raza  info.registry.people.Sultan Ahmed (2)  \
#  0                         153c67dc                               07687c15
#
#    info.registry.people.TP Ura info.registry.people.WT Gavera  \
#  0                    a82eb3fb                       7516045a
#
#                                   info.teams info.toss.decision  \
#  0  [United Arab Emirates, Papua New Guinea]              field
#
#     info.toss.winner              info.umpires            info.venue match_id
#  0  Papua New Guinea  [Akbar Ali, Shozab Raza]  Sheikh Zayed Stadium       17
#
#  [1 rows x 46 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Papua New Guinea', ...               0.91
#
#    meta.created  meta.revision  info.balls_per_over  info.city    info.dates  \
#  0   2017-04-14              1                    6  Abu Dhabi  [2017-04-14]
#
#    info.gender info.match_type  info.outcome.by.wickets  ...  \
#  0        male             T20                        5  ...
#
#    info.registry.people.Shozab Raza  info.registry.people.TP Ura  \
#  0                         153c67dc                     a82eb3fb
#
#    info.registry.people.WT Gavera info.registry.people.Zahoor Khan  \
#  0                       7516045a                         f0e293b0
#
#                                   info.teams info.toss.decision  \
#  0  [United Arab Emirates, Papua New Guinea]                bat
#
#     info.toss.winner              info.umpires            info.venue match_id
#  0  Papua New Guinea  [Akbar Ali, Shozab Raza]  Sheikh Zayed Stadium       18
#
#  [1 rows x 46 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'England', 'deliveri...               0.91
#
#    meta.created  meta.revision  info.balls_per_over   info.city    info.dates  \
#  0   2020-07-06              1                    6  Birmingham  [2018-06-27]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     679  ...
#
#    info.registry.people.RJ Bailey  info.registry.people.RS Madugalle  \
#  0                       6bd04fa5                           766b5798
#
#     info.registry.people.RT Robinson info.registry.people.TM Head  \
#  0                          b143c87d                     12b610c2
#
#               info.teams info.toss.decision info.toss.winner  \
#  0  [England, Australia]              field        Australia
#
#             info.umpires info.venue match_id
#  0  [MA Gough, AG Wharf]  Edgbaston       19
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'England', 'deliveri...               0.91
#
#    meta.created  meta.revision  info.balls_per_over   info.city    info.dates  \
#  0   2020-07-06              1                    6  Manchester  [2018-07-03]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     684  ...
#
#    info.registry.people.SK Raina  info.registry.people.UT Yadav  \
#  0                      1dc12ab9                       cc1e8c68
#
#     info.registry.people.V Kohli info.registry.people.YS Chahal  \
#  0                      ba607b88                       57ee1fde
#
#           info.teams info.toss.decision info.toss.winner  \
#  0  [England, India]              field            India
#
#              info.umpires    info.venue match_id
#  0  [AG Wharf, RJ Bailey]  Old Trafford       20
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'India', 'deliveries...               0.91
#
#    meta.created  meta.revision  info.balls_per_over  info.city    info.dates  \
#  0   2020-07-06              1                    6  Cape Town  [2018-02-24]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     655  ...
#
#    info.registry.people.S George  info.registry.people.SK Raina  \
#  0                      6d9e5a54                       1dc12ab9
#
#     info.registry.people.SN Thakur info.registry.people.T Shamsi  \
#  0                        1abb78f8                      a03bba42
#
#                info.teams info.toss.decision info.toss.winner  \
#  0  [India, South Africa]              field     South Africa
#
#            info.umpires info.venue match_id
#  0  [BP Jele, S George]   Newlands       21
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-08-08              1                    6    Mumbai  [2017-12-24]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     635  ...
#
#    info.registry.people.S Samarawickrama  info.registry.people.SS Iyer  \
#  0                              9ab2914d                      85ec8e33
#
#     info.registry.people.WU Tharanga info.registry.people.Washington Sundar  \
#  0                          7ed9fd56                               f19ccfad
#
#             info.teams info.toss.decision info.toss.winner  \
#  0  [Sri Lanka, India]              field            India
#
#                    info.umpires        info.venue match_id
#  0  [AK Chaudhary, Nitin Menon]  Wankhede Stadium       22
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'West Indies', 'deli...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-08-08              2                    6   Antigua  [2017-10-21]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     385  ...
#
#    info.registry.people.RS Vandort  info.registry.people.SC Selman  \
#  0                        80e193fa                        c29ada99
#
#     info.registry.people.SR Taylor info.registry.people.SS Weerakkody  \
#  0                        92cf79a8                           5f862ccd
#
#                   info.teams info.toss.decision info.toss.winner  \
#  0  [West Indies, Sri Lanka]                bat      West Indies
#
#                  info.umpires               info.venue match_id
#  0  [JM Williams, CM Tuckett]  Coolidge Cricket Ground       23
#
#  [1 rows x 47 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'South Africa', 'del...               0.91
#
#    meta.created  meta.revision  info.balls_per_over      info.city  \
#  0   2020-06-25              1                    6  Potchefstroom
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2018-02-13]      female             T20                     394  ...
#
#    info.registry.people.Siphelele Gasa  info.registry.people.Stephen Harris  \
#  0                            e50baa87                             fdcfd4aa
#
#     info.registry.people.T Bhatia info.registry.people.V Krishnamurthy  \
#  0                       211dc1ce                             c3f21798
#
#                info.teams info.toss.decision info.toss.winner  \
#  0  [South Africa, India]              field            India
#
#                   info.umpires   info.venue match_id
#  0  [Siphelele Gasa, LB Gcuma]  Senwes Park       24
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Bangladesh', 'deliv...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-07-06              1                    6     Dhaka  [2018-02-15]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     648  ...
#
#    info.registry.people.Sharfuddoula  info.registry.people.Soumya Sarkar  \
#  0                          63896abb                            4d9f9686
#
#     info.registry.people.WU Tharanga info.registry.people.Zakir Hasan  \
#  0                          7ed9fd56                         e3e09091
#
#                  info.teams info.toss.decision info.toss.winner  \
#  0  [Bangladesh, Sri Lanka]                bat       Bangladesh
#
#                      info.umpires                             info.venue  \
#  0  [Sharfuddoula, Anisur Rahman]  Shere Bangla National Stadium, Mirpur
#
#    match_id
#  0       25
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
#
#    meta.created  meta.revision  info.balls_per_over    info.dates info.gender  \
#  0   2020-07-06              1                    6  [2018-02-18]        male
#
#    info.match_type  info.match_type_number info.outcome.winner  ...  \
#  0             T20                     651           Sri Lanka  ...
#
#     info.registry.people.Sharfuddoula  info.registry.people.Soumya Sarkar  \
#  0                           63896abb                            4d9f9686
#
#    info.registry.people.Tamim Iqbal info.registry.people.WU Tharanga  \
#  0                         3b041a12                         7ed9fd56
#
#                  info.teams info.toss.decision info.toss.winner  \
#  0  [Sri Lanka, Bangladesh]              field       Bangladesh
#
#                       info.umpires                            info.venue  \
#  0  [Sharfuddoula, Masudur Rahman]  Sylhet International Cricket Stadium
#
#    match_id
#  0       26
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Australia', 'delive...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-06-26              1                    6    Mumbai  [2018-03-31]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     411  ...
#
#    info.registry.people.RL Haynes  info.registry.people.S Ecclestone  \
#  0                       d7c6b0fb                           cdb82f1c
#
#     info.registry.people.TT Beaumont info.registry.people.UV Gandhe  \
#  0                          b2664905                       43dd4011
#
#               info.teams info.toss.decision info.toss.winner  \
#  0  [Australia, England]              field          England
#
#                          info.umpires         info.venue match_id
#  0  [KN Ananthapadmanabhan, R Pandit]  Brabourne Stadium       27
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'India', 'deliveries...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-07-06              1                    6   Colombo  [2018-03-14]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     660  ...
#
#    info.registry.people.Tamim Iqbal  info.registry.people.V Shankar  \
#  0                         3b041a12                        0994d0ae
#
#     info.registry.people.Washington Sundar info.registry.people.YS Chahal  \
#  0                                f19ccfad                       57ee1fde
#
#              info.teams info.toss.decision info.toss.winner  \
#  0  [India, Bangladesh]              field       Bangladesh
#
#                       info.umpires                       info.venue match_id
#  0  [REJ Martinesz, RR Wimalasiri]  R.Premadasa Stadium, Khettarama       28
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'New Zealand', 'deli...               0.91
#
#    meta.created  meta.revision  info.balls_per_over        info.city  \
#  0   2020-06-26              1                    6  Mount Maunganui
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2018-03-14]      female             T20                     399  ...
#
#    info.registry.people.SFM Devine  info.registry.people.SR Taylor  \
#  0                        de69af96                        92cf79a8
#
#     info.registry.people.SS Connell info.registry.people.SW Bates  \
#  0                         2f9a6bd1                      89bbc67a
#
#                     info.teams info.toss.decision info.toss.winner  \
#  0  [New Zealand, West Indies]              field      West Indies
#
#             info.umpires info.venue match_id
#  0  [BF Bowden, K Cross]   Bay Oval       29
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Pakistan', 'deliver...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-06-26              1                    6   Colombo  [2018-03-30]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     410  ...
#
#    info.registry.people.Sana Mir  info.registry.people.Sidra Ameen  \
#  0                      b287e7b1                          72c9ad99
#
#     info.registry.people.Susantha Dissanayake info.registry.people.WC Labrooy  \
#  0                                   7403e05b                        29d4e29b
#
#                info.teams info.toss.decision info.toss.winner  \
#  0  [Pakistan, Sri Lanka]                bat         Pakistan
#
#                      info.umpires                        info.venue match_id
#  0  [AG Dissanayake, PN Udawatta]  Nondescripts Cricket Club Ground       30
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'West Indies', 'deli...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-07-06              1                    6   Karachi  [2018-04-03]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     665  ...
#
#    info.registry.people.Shaheen Shah Afridi  info.registry.people.Shoaib Malik  \
#  0                                 45a7e761                           64c34cd0
#
#     info.registry.people.Shozab Raza info.registry.people.Usman Shinwari  \
#  0                          153c67dc                            f0e722e0
#
#                  info.teams info.toss.decision info.toss.winner  \
#  0  [West Indies, Pakistan]                bat      West Indies
#
#                info.umpires        info.venue match_id
#  0  [Aleem Dar, Ahsan Raza]  National Stadium       31
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'India', 'deliveries...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-07-06              1                    6    Dublin  [2018-06-27]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     678  ...
#
#    info.registry.people.Simi Singh  info.registry.people.V Kohli  \
#  0                        c9945bdf                      ba607b88
#
#     info.registry.people.WB Rankin info.registry.people.YS Chahal  \
#  0                        29b89ae8                       57ee1fde
#
#           info.teams info.toss.decision info.toss.winner  \
#  0  [India, Ireland]              field          Ireland
#
#               info.umpires             info.venue match_id
#  0  [M Hawthorne, R Black]  The Village, Malahide       32
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Zimbabwe', 'deliver...               0.91
#
#    meta.created  meta.revision  info.balls_per_over    info.dates info.gender  \
#  0   2020-07-06              1                    6  [2018-07-06]        male
#
#    info.match_type  info.match_type_number info.outcome.winner  ...  \
#  0             T20                     687           Australia  ...
#
#     info.registry.people.TJ Matibiri  info.registry.people.TK Musakanda  \
#  0                          4a3132b1                           9f9b903e
#
#    info.registry.people.TM Head info.registry.people.WP Masakadza  \
#  0                     12b610c2                          4bc0a378
#
#                info.teams info.toss.decision info.toss.winner  \
#  0  [Zimbabwe, Australia]                bat         Zimbabwe
#
#                 info.umpires          info.venue match_id
#  0  [RB Tiffin, TJ Matibiri]  Harare Sports Club       33
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'South Africa', 'del...               0.91
#
#    meta.created  meta.revision  info.balls_per_over    info.city    info.dates  \
#  0   2020-07-06              1                    6  East London  [2018-10-09]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     698  ...
#
#    info.registry.people.SC Williams  info.registry.people.T Shamsi  \
#  0                         afe57f7a                       a03bba42
#
#     info.registry.people.TK Musakanda info.registry.people.TS Chisoro  \
#  0                           9f9b903e                        4b2d6789
#
#                   info.teams info.toss.decision info.toss.winner  \
#  0  [South Africa, Zimbabwe]                bat     South Africa
#
#                 info.umpires    info.venue match_id
#  0  [AT Holdstock, S George]  Buffalo Park       34
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'South Africa', 'del...               0.91
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2020-01-12              1                    6  Johannesburg
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2019-02-03]        male             T20                     734  ...
#
#    info.registry.people.Shaheen Shah Afridi  info.registry.people.Shoaib Malik  \
#  0                                 45a7e761                           64c34cd0
#
#     info.registry.people.T Shamsi info.registry.people.Usman Shinwari  \
#  0                       a03bba42                            f0e722e0
#
#                   info.teams info.toss.decision info.toss.winner  \
#  0  [South Africa, Pakistan]              field         Pakistan
#
#                  info.umpires             info.venue match_id
#  0  [A Paleker, AT Holdstock]  The Wanderers Stadium       35
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Australia', 'delive...               0.91
#
#    meta.created  meta.revision  info.balls_per_over    info.dates info.gender  \
#  0   2020-07-06              1                    6  [2018-11-25]        male
#
#    info.match_type  info.match_type_number info.outcome.winner  ...  \
#  0             T20                     714               India  ...
#
#     info.registry.people.RR Pant  info.registry.people.S Dhawan  \
#  0                      919a3be2                       0a476045
#
#    info.registry.people.SD Fry info.registry.people.V Kohli  \
#  0                    6b725ed1                     ba607b88
#
#             info.teams info.toss.decision info.toss.winner  \
#  0  [Australia, India]                bat        Australia
#
#             info.umpires             info.venue match_id
#  0  [P Wilson, GA Abood]  Sydney Cricket Ground       36
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Bangladesh', 'deliv...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-07-06              1                    6  St Kitts  [2018-07-31]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     692  ...
#
#    info.registry.people.S Badree  info.registry.people.Shakib Al Hasan  \
#  0                      76388dc8                              7dc35884
#
#    info.registry.people.Soumya Sarkar  info.registry.people.Tamim Iqbal  \
#  0                           4d9f9686                          3b041a12
#
#                    info.teams info.toss.decision info.toss.winner  \
#  0  [Bangladesh, West Indies]              field      West Indies
#
#                   info.umpires               info.venue match_id
#  0  [JS Wilson, GO Brathwaite]  Warner Park, Basseterre       37
#
#  [1 rows x 50 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Bangladesh', 'deliv...               0.91
#
#    meta.created  meta.revision  info.balls_per_over   info.city    info.dates  \
#  0   2020-07-06              1                    6  Lauderhill  [2018-08-05]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     694  ...
#
#    info.registry.people.Sabbir Rahman  info.registry.people.Shakib Al Hasan  \
#  0                           7147f314                              7dc35884
#
#    info.registry.people.Soumya Sarkar  info.registry.people.Tamim Iqbal  \
#  0                           4d9f9686                          3b041a12
#
#                    info.teams info.toss.decision info.toss.winner  \
#  0  [Bangladesh, West Indies]                bat       Bangladesh
#
#                  info.umpires  \
#  0  [N Duguid, GO Brathwaite]
#
#                                            info.venue match_id
#  0  Central Broward Regional Park Stadium Turf Ground       38
#
#  [1 rows x 51 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Uganda', 'deliverie...               0.91
#
#    meta.created  meta.revision  info.balls_per_over   info.city    info.dates  \
#  0   2020-06-29              1                    6  Amstelveen  [2018-07-07]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     444  ...
#
#    info.registry.people.RV Scholes  info.registry.people.S Kemigisha  \
#  0                        2dc78362                          05026222
#
#     info.registry.people.SJ Bryce info.registry.people.WPM van Liemt  \
#  0                       2ca65aee                           2bd48588
#
#             info.teams info.toss.decision info.toss.winner  \
#  0  [Uganda, Scotland]              field         Scotland
#
#              info.umpires  info.venue match_id
#  0  [CA Polosak, R Black]  VRA Ground       39
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Papua New Guinea', ...               0.91
#
#    meta.created  meta.revision  info.balls_per_over   info.city    info.dates  \
#  0   2020-06-29              1                    6  Amstelveen  [2018-07-07]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     446  ...
#
#    info.registry.people.T Ruma  info.registry.people.V Araa  \
#  0                    3697a0ff                     040f11e8
#
#     info.registry.people.V Frank info.registry.people.WPM van Liemt  \
#  0                      4f58d65d                           2bd48588
#
#                         info.teams info.toss.decision info.toss.winner  \
#  0  [Papua New Guinea, Bangladesh]              field       Bangladesh
#
#                    info.umpires  info.venue match_id
#  0  [CA Polosak, WPM van Liemt]  VRA Ground       40
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Scotland', 'deliver...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-06-29              1                    6   Utrecht  [2018-07-10]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     451  ...
#
#    info.registry.people.S Tippoch  info.registry.people.SJ Bryce  \
#  0                       9c4b58db                       2ca65aee
#
#     info.registry.people.W Liengprasert info.registry.people.WPM van Liemt  \
#  0                             4dabe716                           2bd48588
#
#               info.teams info.toss.decision info.toss.winner  \
#  0  [Scotland, Thailand]                bat         Scotland
#
#                    info.umpires                   info.venue match_id
#  0  [CA Polosak, WPM van Liemt]  Sportpark Maarschalkerweerd       41
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Uganda', 'deliverie...               0.91
#
#    meta.created  meta.revision  info.balls_per_over   info.city    info.dates  \
#  0   2020-06-29              1                    6  Amstelveen  [2018-07-10]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     452  ...
#
#    info.registry.people.R Ntono  info.registry.people.S Nampiina  \
#  0                     4b6da99c                         91d9aa26
#
#     info.registry.people.S Redfern info.registry.people.SM Kavanagh  \
#  0                        5b038989                         7e9b3b60
#
#            info.teams info.toss.decision info.toss.winner  \
#  0  [Uganda, Ireland]              field          Ireland
#
#                          info.umpires  info.venue match_id
#  0  [Ahmed Shah Pakteen, JM Williams]  VRA Ground       42
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'United Arab Emirate...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-06-29              1                    6   Utrecht  [2018-07-10]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     453  ...
#
#    info.registry.people.Sanjida Islam  info.registry.people.Shamima Sultana  \
#  0                           12755a62                              724645f5
#
#     info.registry.people.UCKA Dona info.registry.people.WPM van Liemt  \
#  0                        caa99fcb                           2bd48588
#
#                             info.teams info.toss.decision info.toss.winner  \
#  0  [United Arab Emirates, Bangladesh]              field       Bangladesh
#
#                 info.umpires                   info.venue match_id
#  0  [R Black, WPM van Liemt]  Sportpark Maarschalkerweerd       43
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Ireland', 'deliveri...               0.91
#
#    meta.created  meta.revision  info.balls_per_over   info.city    info.dates  \
#  0   2020-06-29              1                    6  Amstelveen  [2018-07-12]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     455  ...
#
#    info.registry.people.SM Kavanagh  info.registry.people.T Ruma  \
#  0                         7e9b3b60                     3697a0ff
#
#     info.registry.people.V Araa info.registry.people.V Frank  \
#  0                     040f11e8                     4f58d65d
#
#                      info.teams info.toss.decision  info.toss.winner  \
#  0  [Ireland, Papua New Guinea]              field  Papua New Guinea
#
#                  info.umpires  info.venue match_id
#  0  [CA Polosak, JM Williams]  VRA Ground       44
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Thailand', 'deliver...               0.91
#
#    meta.created  meta.revision  info.balls_per_over   info.city    info.dates  \
#  0   2020-06-29              1                    6  Amstelveen  [2018-07-14]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     461  ...
#
#    info.registry.people.S Saengsakaorat  info.registry.people.S Tippoch  \
#  0                             6214c0c6                        9c4b58db
#
#     info.registry.people.W Liengprasert info.registry.people.WPM van Liemt  \
#  0                             4dabe716                           2bd48588
#
#             info.teams info.toss.decision info.toss.winner  \
#  0  [Thailand, Uganda]              field           Uganda
#
#                 info.umpires  info.venue match_id
#  0  [R Black, WPM van Liemt]  VRA Ground       45
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Thailand', 'deliver...               0.91
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2020-06-30              1                    6  Kuala Lumpur
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2018-06-07]      female             T20                     426  ...
#
#    info.registry.people.Shamima Sultana  info.registry.people.V Kalidas  \
#  0                             724645f5                        42d76418
#
#     info.registry.people.W Liengprasert info.registry.people.WC Labrooy  \
#  0                             4dabe716                        29d4e29b
#
#                 info.teams info.toss.decision info.toss.winner  \
#  0  [Thailand, Bangladesh]              field       Bangladesh
#
#             info.umpires            info.venue match_id
#  0  [N Sivan, V Kalidas]  Kinrara Academy Oval       46
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Pakistan', 'deliver...               0.91
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2020-06-30              1                    6  Kuala Lumpur
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2018-06-09]      female             T20                     429  ...
#
#    info.registry.people.Sarika Prasad  info.registry.people.Sidra Nawaz  \
#  0                           8ff397fa                          ca3ded6f
#
#     info.registry.people.T Bhatia info.registry.people.V Krishnamurthy  \
#  0                       211dc1ce                             c3f21798
#
#            info.teams info.toss.decision info.toss.winner  \
#  0  [Pakistan, India]                bat         Pakistan
#
# ...
#  0  [Thailand, Singapore]         Thailand                bat
#
#                          info.umpires                         info.venue  \
#  0  [Aasif Iqbal, Gayathri Venugopal]  Royal Selangor Club, Kuala Lumpur
#
#    match_id
#  0      985
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Japan', 'deliveries...               0.92
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2024-02-13              1                    6  Kuala Lumpur
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2024-02-13]      female             T20                    1775  ...
#
#    info.registry.people.S Kotte  info.registry.people.Seika Sumi  \
#  0                     6c8904c8                         704b4c30
#
#     info.registry.people.Theertha Satish info.registry.people.Vaishnave Mahesh  \
#  0                              ee3dcb3f                              31c56f40
#
#                        info.teams info.toss.winner info.toss.decision  \
#  0  [Japan, United Arab Emirates]            Japan                bat
#
#                         info.umpires                        info.venue match_id
#  0  [Nur Hijrah, Ramasamy Venkatesh]  Selangor Turf Club, Kuala Lumpur      986
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Qatar', 'deliveries...               0.92
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2024-02-13              1                    6  Kuala Lumpur
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2024-02-13]      female             T20                    1776  ...
#
#    info.registry.people.Saleema Imtiaz  info.registry.people.T Kale  \
#  0                            d17d21d5                     bc9bd4c6
#
#     info.registry.people.V Bowen info.registry.people.Zahid Usman  \
#  0                      7297ac4d                         5ee3b5bd
#
#             info.teams info.toss.winner info.toss.decision  \
#  0  [Qatar, Indonesia]        Indonesia              field
#
#                      info.umpires                   info.venue match_id
#  0  [Saleema Imtiaz, Zahid Usman]  Bayuemas Oval, Kuala Lumpur      987
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Nepal', 'deliveries...               0.92
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2024-02-13              1                    6     Bangi  [2024-02-13]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                    1777  ...
#
#    info.registry.people.Shamma Ali  info.registry.people.Shathira Jakir  \
#  0                        012bd3f6                             6b992a6f
#
#     info.registry.people.Shriya Kumari info.registry.people.Sumayya Abdul  \
#  0                            5e452781                           a521ba3e
#
#            info.teams info.toss.winner info.toss.decision  \
#  0  [Nepal, Maldives]            Nepal                bat
#
#                     info.umpires                   info.venue match_id
#  0  [L Poobalan, Shathira Jakir]  YSD-UKM Cricket Oval, Bangi      988
#
#  [1 rows x 47 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Hong Kong', 'delive...               0.92
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2024-02-14              1                    6  Kuala Lumpur
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2024-02-14]      female             T20                    1778  ...
#
#    info.registry.people.Shivani Mishra  info.registry.people.T Putthawong  \
#  0                            2982a0c7                           23e3f2d6
#
#     info.registry.people.V Bowen info.registry.people.Y Daswani  \
#  0                      7297ac4d                       2038a273
#
#                info.teams info.toss.winner info.toss.decision  \
#  0  [Hong Kong, Thailand]         Thailand              field
#
#                info.umpires                   info.venue match_id
#  0  [Aasif Iqbal, N Perera]  Bayuemas Oval, Kuala Lumpur      989
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'United Arab Emirate...               0.92
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2024-02-14              1                    6     Bangi  [2024-02-14]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                    1779  ...
#
#    info.registry.people.Saleema Imtiaz  info.registry.people.Shathira Jakir  \
#  0                            d17d21d5                             6b992a6f
#
#     info.registry.people.Theertha Satish info.registry.people.Vaishnave Mahesh  \
#  0                              ee3dcb3f                              31c56f40
#
#                            info.teams      info.toss.winner info.toss.decision  \
#  0  [United Arab Emirates, Indonesia]  United Arab Emirates                bat
#
#                         info.umpires                   info.venue match_id
#  0  [Saleema Imtiaz, Shathira Jakir]  YSD-UKM Cricket Oval, Bangi      990
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Malaysia', 'deliver...               0.92
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2024-02-14              1                    6  Kuala Lumpur
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2024-02-14]      female             T20                    1780  ...
#
#    info.registry.people.Siow Tzin Yee  info.registry.people.V Bowen  \
#  0                           686b7194                      7297ac4d
#
#     info.registry.people.WA Duraisingam info.registry.people.Wan Julia  \
#  0                             7467fe01                       bee0c85c
#
#            info.teams info.toss.winner info.toss.decision  \
#  0  [Malaysia, Japan]         Malaysia                bat
#
#                      info.umpires                   info.venue match_id
#  0  [Aasif Iqbal, Shivani Mishra]  Bayuemas Oval, Kuala Lumpur      991
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Kuwait', 'deliverie...               0.92
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2024-02-14              1                    6     Bangi  [2024-02-14]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                    1781  ...
#
#    info.registry.people.SR Magar  info.registry.people.Saleema Imtiaz  \
#  0                      61c22ad0                             d17d21d5
#
#    info.registry.people.Shathira Jakir  info.registry.people.Zeefa Jilani  \
#  0                            6b992a6f                           3f2b40f0
#
#          info.teams info.toss.winner info.toss.decision  \
#  0  [Kuwait, Nepal]           Kuwait                bat
#
#                     info.umpires                   info.venue match_id
#  0  [Nur Hijrah, Saleema Imtiaz]  YSD-UKM Cricket Oval, Bangi      992
#
#  [1 rows x 50 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'United Arab Emirate...               0.92
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2024-02-19              1                    6  Kuala Lumpur
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2024-02-16]      female             T20                    1782  ...
#
#    info.registry.people.T Putthawong  info.registry.people.Theertha Satish  \
#  0                          23e3f2d6                              ee3dcb3f
#
#     info.registry.people.V Bowen info.registry.people.Vaishnave Mahesh  \
#  0                      7297ac4d                              31c56f40
#
#                           info.teams      info.toss.winner info.toss.decision  \
#  0  [United Arab Emirates, Thailand]  United Arab Emirates                bat
#
#                         info.umpires                   info.venue match_id
#  0  [Gayathri Venugopal, Nur Hijrah]  Bayuemas Oval, Kuala Lumpur      993
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Nepal', 'deliveries...               0.92
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2024-02-19              1                    6  Kuala Lumpur
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2024-02-16]      female             T20                    1783  ...
#
#    info.registry.people.Siow Tzin Yee  info.registry.people.V Bowen  \
#  0                           686b7194                      7297ac4d
#
#     info.registry.people.WA Duraisingam info.registry.people.Wan Julia  \
#  0                             7467fe01                       bee0c85c
#
#            info.teams info.toss.winner info.toss.decision  \
#  0  [Nepal, Malaysia]            Nepal                bat
#
#                info.umpires                   info.venue match_id
#  0  [Aasif Iqbal, N Perera]  Bayuemas Oval, Kuala Lumpur      994
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'United Arab Emirate...               0.92
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2024-02-19              1                    6  Kuala Lumpur
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2024-02-18]      female             T20                    1784  ...
#
#    info.registry.people.Theertha Satish  info.registry.people.Vaishnave Mahesh  \
#  0                             ee3dcb3f                               31c56f40
#
#     info.registry.people.WA Duraisingam info.registry.people.Wan Julia  \
#  0                             7467fe01                       bee0c85c
#
#                           info.teams      info.toss.winner info.toss.decision  \
#  0  [United Arab Emirates, Malaysia]  United Arab Emirates                bat
#
#                       info.umpires                   info.venue match_id
#  0  [Gayathri Venugopal, N Perera]  Bayuemas Oval, Kuala Lumpur      995
#
#  [1 rows x 47 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Zimbabwe', 'deliver...               0.92
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2024-07-06              1                    6    Harare  [2024-07-06]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                    2737  ...
#
#    info.registry.people.TL Chatara  info.registry.people.W Madhevere  \
#  0                        5bbabe59                          a879b92c
#
#     info.registry.people.WP Masakadza info.registry.people.Washington Sundar  \
#  0                           4bc0a378                               f19ccfad
#
#            info.teams info.toss.winner info.toss.decision  \
#  0  [Zimbabwe, India]            India              field
#
#             info.umpires          info.venue match_id
#  0  [F Mutizwa, I Chabi]  Harare Sports Club      996
#
#  [1 rows x 50 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'India', 'deliveries...               0.92
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2024-07-08              1                    6    Harare  [2024-07-07]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                    2739  ...
#
#    info.registry.people.TL Chatara  info.registry.people.W Madhevere  \
#  0                        5bbabe59                          a879b92c
#
#     info.registry.people.WP Masakadza info.registry.people.Washington Sundar  \
#  0                           4bc0a378                               f19ccfad
#
#            info.teams info.toss.winner info.toss.decision  \
#  0  [India, Zimbabwe]            India                bat
#
#              info.umpires          info.venue match_id
#  0  [F Mutizwa, L Rusere]  Harare Sports Club      997
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'India', 'deliveries...               0.92
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2024-07-11              1                    6    Harare  [2024-07-10]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                    2749  ...
#
#    info.registry.people.W Madhevere  info.registry.people.WP Masakadza  \
#  0                         a879b92c                           4bc0a378
#
#     info.registry.people.Washington Sundar info.registry.people.YBK Jaiswal  \
#  0                                f19ccfad                         6c19c6e5
#
#            info.teams info.toss.winner info.toss.decision  \
#  0  [India, Zimbabwe]            India                bat
#
#             info.umpires          info.venue match_id
#  0  [L Rusere, P Sizara]  Harare Sports Club      998
#
#  [1 rows x 50 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Zimbabwe', 'deliver...               0.92
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2024-07-24              1                    6    Harare  [2024-07-13]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                    2759  ...
#
#    info.registry.people.TU Deshpande  info.registry.people.W Madhevere  \
#  0                          46a9bea1                          a879b92c
#
#     info.registry.people.Washington Sundar info.registry.people.YBK Jaiswal  \
#  0                                f19ccfad                         6c19c6e5
#
#            info.teams info.toss.winner info.toss.decision  \
#  0  [Zimbabwe, India]            India              field
#
#             info.umpires          info.venue match_id
#  0  [F Mutizwa, I Chabi]  Harare Sports Club      999
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'India', 'deliveries...               0.92
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2024-07-24              1                    6    Harare  [2024-07-14]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                    2762  ...
#
#    info.registry.people.TU Deshpande  info.registry.people.W Madhevere  \
#  0                          46a9bea1                          a879b92c
#
#     info.registry.people.Washington Sundar info.registry.people.YBK Jaiswal  \
#  0                                f19ccfad                         6c19c6e5
#
#            info.teams info.toss.winner info.toss.decision  \
#  0  [India, Zimbabwe]         Zimbabwe              field
#
#             info.umpires          info.venue match_id
#  0  [F Mutizwa, I Chabi]  Harare Sports Club     1000
#
#  [1 rows x 49 columns],
#  ...]

# %%
final_df.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 final_df.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
final_df
# Out:
# [                                             innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'New Zealand', 'deli...               0.91
#
#    meta.created  meta.revision  info.balls_per_over        info.city  \
#  0   2017-01-08              1                    6  Mount Maunganui
#
#       info.dates info.gender info.match_type  info.outcome.by.runs  ...  \
#  0  [2017-01-06]        male             T20                    47  ...
#
#    info.registry.people.TA Boult  info.registry.people.TC Bruce  \
#  0                      a818c1be                       f92c9151
#
#    info.registry.people.Tamim Iqbal info.registry.people.WR Knights  \
#  0                         3b041a12                        63cbf8d8
#
#                    info.teams info.toss.decision info.toss.winner  \
#  0  [New Zealand, Bangladesh]              field       Bangladesh
#
#            info.umpires info.venue match_id
#  0  [CM Brown, SB Haig]   Bay Oval        1
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'New Zealand', 'deli...               0.91
#
#    meta.created  meta.revision  info.balls_per_over        info.city  \
#  0   2017-01-08              2                    6  Mount Maunganui
#
#       info.dates info.gender info.match_type  info.outcome.by.runs  ...  \
#  0  [2017-01-08]        male             T20                    27  ...
#
#    info.registry.people.TC Bruce  info.registry.people.Tamim Iqbal  \
#  0                      f92c9151                          3b041a12
#
#    info.registry.people.Taskin Ahmed info.registry.people.WR Knights  \
#  0                          ef18b66e                        63cbf8d8
#
#                    info.teams info.toss.decision info.toss.winner  \
#  0  [New Zealand, Bangladesh]              field       Bangladesh
#
#               info.umpires info.venue match_id
#  0  [CM Brown, WR Knights]   Bay Oval        2
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'South Africa', 'del...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2017-02-18              1                    6  Auckland  [2017-02-17]
#
#    info.gender info.match_type  info.outcome.by.runs  ...  \
#  0        male             T20                    78  ...
#
#    info.registry.people.TC Bruce  info.registry.people.TG Southee  \
#  0                      f92c9151                         13c35c9e
#
#    info.registry.people.WD Parnell info.registry.people.WR Knights  \
#  0                        3a60e0b5                        63cbf8d8
#
#                      info.teams info.toss.decision info.toss.winner  \
#  0  [New Zealand, South Africa]              field      New Zealand
#
#               info.umpires info.venue match_id
#  0  [CM Brown, WR Knights]  Eden Park        3
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'South Africa', 'del...               0.91
#
#    meta.created  meta.revision  info.balls_per_over    info.city    info.dates  \
#  0   2017-06-24              1                    6  Southampton  [2017-06-21]
#
#    info.gender info.match_type  info.outcome.by.wickets  ...  \
#  0        male             T20                        9  ...
#
#    info.registry.people.RT Robinson  info.registry.people.SW Billings  \
#  0                         b143c87d                          c16d4035
#
#    info.registry.people.T Shamsi info.registry.people.WD Parnell  \
#  0                      a03bba42                        3a60e0b5
#
#                  info.teams info.toss.decision info.toss.winner  \
#  0  [England, South Africa]                bat     South Africa
#
#                 info.umpires     info.venue match_id
#  0  [RJ Bailey, RT Robinson]  The Rose Bowl        4
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'South Africa', 'del...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2017-06-24              1                    6   Taunton  [2017-06-23]
#
#    info.gender info.match_type  info.outcome.by.runs  ...  \
#  0        male             T20                     3  ...
#
#    info.registry.people.RT Robinson  info.registry.people.SW Billings  \
#  0                         b143c87d                          c16d4035
#
#    info.registry.people.T Shamsi info.registry.people.TK Curran  \
#  0                      a03bba42                       e86754b2
#
#                  info.teams info.toss.decision info.toss.winner  \
#  0  [England, South Africa]              field          England
#
#              info.umpires     info.venue match_id
#  0  [RJ Bailey, MA Gough]  County Ground        5
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'New Zealand', 'deli...               0.91
#
#    meta.created  meta.revision  info.balls_per_over    info.dates info.gender  \
#  0   2017-02-23              1                    6  [2017-02-22]      female
#
#    info.match_type  info.outcome.by.runs info.outcome.winner  ...  \
#  0             T20                    47         New Zealand  ...
#
#     info.registry.people.RH Priest info.registry.people.SAJ Craig  \
#  0                        e6f0408a                       689f2eed
#
#    info.registry.people.SR Bernard info.registry.people.SW Bates  \
#  0                        800187dc                      89bbc67a
#
#                   info.teams info.toss.decision info.toss.winner  \
#  0  [Australia, New Zealand]                bat      New Zealand
#
#            info.umpires     info.venue match_id
#  0  [GA Abood, JD Ward]  Adelaide Oval        6
#
#  [1 rows x 47 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Pakistan', 'deliver...               0.91
#
#    meta.created  meta.revision  info.balls_per_over    info.dates info.gender  \
#  0   2016-09-29              1                    6  [2016-09-24]        male
#
#    info.match_type  info.neutral_venue  info.outcome.by.runs  ...  \
#  0             T20                   1                    16  ...
#
#    info.registry.people.Shozab Raza  info.registry.people.Sohail Tanvir  \
#  0                         153c67dc                            64d43928
#
#    info.registry.people.Umar Akmal info.registry.people.Wahab Riaz  \
#  0                        fd2bf2a0                        b3118300
#
#                  info.teams info.toss.decision info.toss.winner  \
#  0  [Pakistan, West Indies]              field      West Indies
#
#                    info.umpires                           info.venue match_id
#  0  [Ahmed Shahab, Shozab Raza]  Dubai International Cricket Stadium        7
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'New Zealand', 'deli...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-07-03              1                    6  Auckland  [2018-02-16]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     649  ...
#
#    info.registry.people.TA Boult  info.registry.people.TG Southee  \
#  0                      a818c1be                         13c35c9e
#
#     info.registry.people.TL Seifert info.registry.people.WR Knights  \
#  0                         4663bd23                        63cbf8d8
#
#                   info.teams info.toss.decision info.toss.winner  \
#  0  [New Zealand, Australia]                bat      New Zealand
#
#            info.umpires info.venue match_id
#  0  [P Wilson, SB Haig]  Eden Park        8
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Scotland', 'deliver...               0.91
#
#    meta.created  meta.revision  info.balls_per_over  info.city    info.dates  \
#  0   2017-01-18              2                    6  Abu Dhabi  [2017-01-14]
#
#    info.gender info.match_type  info.neutral_venue  ...  \
#  0        male             T20                   1  ...
#
#     info.registry.people.Shahid Wasif info.registry.people.Tanveer Ahmed  \
#  0                           2cc08c3c                           571f11e4
#
#     info.registry.people.Waqas Barkat info.registry.people.Waqas Khan  \
#  0                           a2eac9df                        35971419
#
#                info.teams info.toss.decision info.toss.winner  \
#  0  [Hong Kong, Scotland]                bat         Scotland
#
#                       info.umpires            info.venue match_id
#  0  [Ahmed Shah Pakteen, AJ Neill]  Sheikh Zayed Stadium        9
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Hong Kong', 'delive...               0.91
#
#    meta.created  meta.revision  info.balls_per_over  info.city    info.dates  \
#  0   2017-01-18              1                    6  Abu Dhabi  [2017-01-16]
#
#    info.gender info.match_type  info.neutral_venue  ...  \
#  0        male             T20                   1  ...
#
#     info.registry.people.Sultan Ahmed info.registry.people.Tanveer Ahmed  \
#  0                           3bf7c034                           571f11e4
#
#     info.registry.people.Waqas Khan info.registry.people.Zeeshan Maqsood  \
#  0                         35971419                             34464143
#
#            info.teams info.toss.decision info.toss.winner  \
#  0  [Hong Kong, Oman]              field             Oman
#
#                 info.umpires            info.venue match_id
#  0  [Iftikhar Ali, AJ Neill]  Sheikh Zayed Stadium       10
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Scotland', 'deliver...               0.91
#
#    meta.created  meta.revision  info.balls_per_over  info.city    info.dates  \
#  0   2017-01-18              1                    6  Abu Dhabi  [2017-01-17]
#
#    info.gender info.match_type  info.neutral_venue  ...  \
#  0        male             T20                   1  ...
#
#     info.registry.people.T van der Gugten info.registry.people.TP Visee  \
#  0                               d99cc23a                      881b3f8e
#
#     info.registry.people.Tabarak Dar info.registry.people.W Barresi  \
#  0                          2259c12d                       0d677597
#
#                  info.teams info.toss.decision info.toss.winner  \
#  0  [Netherlands, Scotland]              field      Netherlands
#
#                info.umpires            info.venue match_id
#  0  [AJ Neill, Tabarak Dar]  Sheikh Zayed Stadium       11
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Ireland', 'deliveri...               0.91
#
#    meta.created  meta.revision  info.balls_per_over    info.dates info.gender  \
#  0   2017-01-18              2                    6  [2017-01-18]        male
#
#    info.match_type  info.outcome.by.runs info.outcome.winner  ...  \
#  0             T20                    24             Ireland  ...
#
#     info.registry.people.Shaiman Anwar info.registry.people.WB Rankin  \
#  0                            e9630504                       29b89ae8
#
#    info.registry.people.WTS Porterfield info.registry.people.Zahoor Khan  \
#  0                             ec02b798                         f0e293b0
#
#                          info.teams info.toss.decision info.toss.winner  \
#  0  [United Arab Emirates, Ireland]                bat          Ireland
#
#                         info.umpires                           info.venue  \
#  0  [Ahmed Shah Durrani, BB Pradhan]  Dubai International Cricket Stadium
#
#    match_id
#  0       12
#
#  [1 rows x 46 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'England', 'deliveri...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-08-08              1                    6    Sydney  [2017-11-17]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     391  ...
#
#    info.registry.people.SE Aley  info.registry.people.SJ Taylor  \
#  0                     5be043df                        e6f36f83
#
#     info.registry.people.SR Bernard info.registry.people.TT Beaumont  \
#  0                         800187dc                         b2664905
#
#               info.teams info.toss.decision info.toss.winner  \
#  0  [England, Australia]              field        Australia
#
#               info.umpires         info.venue match_id
#  0  [GC Joshua, SAJ Craig]  North Sydney Oval       13
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'England', 'deliveri...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-08-08              1                    6  Canberra  [2017-11-19]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     392  ...
#
#    info.registry.people.SE Aley  info.registry.people.SJ Taylor  \
#  0                     5be043df                        e6f36f83
#
#     info.registry.people.SR Bernard info.registry.people.TT Beaumont  \
#  0                         800187dc                         b2664905
#
#               info.teams info.toss.decision info.toss.winner  \
#  0  [England, Australia]                bat          England
#
#             info.umpires   info.venue match_id
#  0  [JD Ward, GC Joshua]  Manuka Oval       14
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Australia', 'delive...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-08-08              1                    6  Canberra  [2017-11-21]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     393  ...
#
#    info.registry.people.SAJ Craig  info.registry.people.SJ Taylor  \
#  0                       689f2eed                        e6f36f83
#
#     info.registry.people.SR Bernard info.registry.people.TT Beaumont  \
#  0                         800187dc                         b2664905
#
#               info.teams info.toss.decision info.toss.winner  \
#  0  [Australia, England]                bat        Australia
#
#             info.umpires   info.venue match_id
#  0  [JD Ward, SAJ Craig]  Manuka Oval       15
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Papua New Guinea', ...               0.91
#
#    meta.created  meta.revision  info.balls_per_over  info.city    info.dates  \
#  0   2017-04-12              2                    6  Abu Dhabi  [2017-04-12]
#
#    info.gender info.match_type  info.outcome.by.wickets  ...  \
#  0        male             T20                        5  ...
#
#    info.registry.people.Sultan Ahmed (2)  info.registry.people.TP Ura  \
#  0                              07687c15                     a82eb3fb
#
#    info.registry.people.VV Morea info.registry.people.WT Gavera  \
#  0                      e64c10dd                       7516045a
#
#                                   info.teams info.toss.decision  \
#  0  [United Arab Emirates, Papua New Guinea]              field
#
#         info.toss.winner              info.umpires            info.venue  \
#  0  United Arab Emirates  [Akbar Ali, Shozab Raza]  Sheikh Zayed Stadium
#
#    match_id
#  0       16
#
#  [1 rows x 46 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'United Arab Emirate...               0.91
#
#    meta.created  meta.revision  info.balls_per_over  info.city    info.dates  \
#  0   2017-04-14              2                    6  Abu Dhabi  [2017-04-14]
#
#    info.gender info.match_type  info.outcome.by.runs  ...  \
#  0        male             T20                    30  ...
#
#    info.registry.people.Shozab Raza  info.registry.people.Sultan Ahmed (2)  \
#  0                         153c67dc                               07687c15
#
#    info.registry.people.TP Ura info.registry.people.WT Gavera  \
#  0                    a82eb3fb                       7516045a
#
#                                   info.teams info.toss.decision  \
#  0  [United Arab Emirates, Papua New Guinea]              field
#
#     info.toss.winner              info.umpires            info.venue match_id
#  0  Papua New Guinea  [Akbar Ali, Shozab Raza]  Sheikh Zayed Stadium       17
#
#  [1 rows x 46 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Papua New Guinea', ...               0.91
#
#    meta.created  meta.revision  info.balls_per_over  info.city    info.dates  \
#  0   2017-04-14              1                    6  Abu Dhabi  [2017-04-14]
#
#    info.gender info.match_type  info.outcome.by.wickets  ...  \
#  0        male             T20                        5  ...
#
#    info.registry.people.Shozab Raza  info.registry.people.TP Ura  \
#  0                         153c67dc                     a82eb3fb
#
#    info.registry.people.WT Gavera info.registry.people.Zahoor Khan  \
#  0                       7516045a                         f0e293b0
#
#                                   info.teams info.toss.decision  \
#  0  [United Arab Emirates, Papua New Guinea]                bat
#
#     info.toss.winner              info.umpires            info.venue match_id
#  0  Papua New Guinea  [Akbar Ali, Shozab Raza]  Sheikh Zayed Stadium       18
#
#  [1 rows x 46 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'England', 'deliveri...               0.91
#
#    meta.created  meta.revision  info.balls_per_over   info.city    info.dates  \
#  0   2020-07-06              1                    6  Birmingham  [2018-06-27]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     679  ...
#
#    info.registry.people.RJ Bailey  info.registry.people.RS Madugalle  \
#  0                       6bd04fa5                           766b5798
#
#     info.registry.people.RT Robinson info.registry.people.TM Head  \
#  0                          b143c87d                     12b610c2
#
#               info.teams info.toss.decision info.toss.winner  \
#  0  [England, Australia]              field        Australia
#
#             info.umpires info.venue match_id
#  0  [MA Gough, AG Wharf]  Edgbaston       19
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'England', 'deliveri...               0.91
#
#    meta.created  meta.revision  info.balls_per_over   info.city    info.dates  \
#  0   2020-07-06              1                    6  Manchester  [2018-07-03]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     684  ...
#
#    info.registry.people.SK Raina  info.registry.people.UT Yadav  \
#  0                      1dc12ab9                       cc1e8c68
#
#     info.registry.people.V Kohli info.registry.people.YS Chahal  \
#  0                      ba607b88                       57ee1fde
#
#           info.teams info.toss.decision info.toss.winner  \
#  0  [England, India]              field            India
#
#              info.umpires    info.venue match_id
#  0  [AG Wharf, RJ Bailey]  Old Trafford       20
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'India', 'deliveries...               0.91
#
#    meta.created  meta.revision  info.balls_per_over  info.city    info.dates  \
#  0   2020-07-06              1                    6  Cape Town  [2018-02-24]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     655  ...
#
#    info.registry.people.S George  info.registry.people.SK Raina  \
#  0                      6d9e5a54                       1dc12ab9
#
#     info.registry.people.SN Thakur info.registry.people.T Shamsi  \
#  0                        1abb78f8                      a03bba42
#
#                info.teams info.toss.decision info.toss.winner  \
#  0  [India, South Africa]              field     South Africa
#
#            info.umpires info.venue match_id
#  0  [BP Jele, S George]   Newlands       21
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-08-08              1                    6    Mumbai  [2017-12-24]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     635  ...
#
#    info.registry.people.S Samarawickrama  info.registry.people.SS Iyer  \
#  0                              9ab2914d                      85ec8e33
#
#     info.registry.people.WU Tharanga info.registry.people.Washington Sundar  \
#  0                          7ed9fd56                               f19ccfad
#
#             info.teams info.toss.decision info.toss.winner  \
#  0  [Sri Lanka, India]              field            India
#
#                    info.umpires        info.venue match_id
#  0  [AK Chaudhary, Nitin Menon]  Wankhede Stadium       22
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'West Indies', 'deli...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-08-08              2                    6   Antigua  [2017-10-21]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     385  ...
#
#    info.registry.people.RS Vandort  info.registry.people.SC Selman  \
#  0                        80e193fa                        c29ada99
#
#     info.registry.people.SR Taylor info.registry.people.SS Weerakkody  \
#  0                        92cf79a8                           5f862ccd
#
#                   info.teams info.toss.decision info.toss.winner  \
#  0  [West Indies, Sri Lanka]                bat      West Indies
#
#                  info.umpires               info.venue match_id
#  0  [JM Williams, CM Tuckett]  Coolidge Cricket Ground       23
#
#  [1 rows x 47 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'South Africa', 'del...               0.91
#
#    meta.created  meta.revision  info.balls_per_over      info.city  \
#  0   2020-06-25              1                    6  Potchefstroom
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2018-02-13]      female             T20                     394  ...
#
#    info.registry.people.Siphelele Gasa  info.registry.people.Stephen Harris  \
#  0                            e50baa87                             fdcfd4aa
#
#     info.registry.people.T Bhatia info.registry.people.V Krishnamurthy  \
#  0                       211dc1ce                             c3f21798
#
#                info.teams info.toss.decision info.toss.winner  \
#  0  [South Africa, India]              field            India
#
#                   info.umpires   info.venue match_id
#  0  [Siphelele Gasa, LB Gcuma]  Senwes Park       24
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Bangladesh', 'deliv...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-07-06              1                    6     Dhaka  [2018-02-15]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     648  ...
#
#    info.registry.people.Sharfuddoula  info.registry.people.Soumya Sarkar  \
#  0                          63896abb                            4d9f9686
#
#     info.registry.people.WU Tharanga info.registry.people.Zakir Hasan  \
#  0                          7ed9fd56                         e3e09091
#
#                  info.teams info.toss.decision info.toss.winner  \
#  0  [Bangladesh, Sri Lanka]                bat       Bangladesh
#
#                      info.umpires                             info.venue  \
#  0  [Sharfuddoula, Anisur Rahman]  Shere Bangla National Stadium, Mirpur
#
#    match_id
#  0       25
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
#
#    meta.created  meta.revision  info.balls_per_over    info.dates info.gender  \
#  0   2020-07-06              1                    6  [2018-02-18]        male
#
#    info.match_type  info.match_type_number info.outcome.winner  ...  \
#  0             T20                     651           Sri Lanka  ...
#
#     info.registry.people.Sharfuddoula  info.registry.people.Soumya Sarkar  \
#  0                           63896abb                            4d9f9686
#
#    info.registry.people.Tamim Iqbal info.registry.people.WU Tharanga  \
#  0                         3b041a12                         7ed9fd56
#
#                  info.teams info.toss.decision info.toss.winner  \
#  0  [Sri Lanka, Bangladesh]              field       Bangladesh
#
#                       info.umpires                            info.venue  \
#  0  [Sharfuddoula, Masudur Rahman]  Sylhet International Cricket Stadium
#
#    match_id
#  0       26
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Australia', 'delive...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-06-26              1                    6    Mumbai  [2018-03-31]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     411  ...
#
#    info.registry.people.RL Haynes  info.registry.people.S Ecclestone  \
#  0                       d7c6b0fb                           cdb82f1c
#
#     info.registry.people.TT Beaumont info.registry.people.UV Gandhe  \
#  0                          b2664905                       43dd4011
#
#               info.teams info.toss.decision info.toss.winner  \
#  0  [Australia, England]              field          England
#
#                          info.umpires         info.venue match_id
#  0  [KN Ananthapadmanabhan, R Pandit]  Brabourne Stadium       27
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'India', 'deliveries...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-07-06              1                    6   Colombo  [2018-03-14]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     660  ...
#
#    info.registry.people.Tamim Iqbal  info.registry.people.V Shankar  \
#  0                         3b041a12                        0994d0ae
#
#     info.registry.people.Washington Sundar info.registry.people.YS Chahal  \
#  0                                f19ccfad                       57ee1fde
#
#              info.teams info.toss.decision info.toss.winner  \
#  0  [India, Bangladesh]              field       Bangladesh
#
#                       info.umpires                       info.venue match_id
#  0  [REJ Martinesz, RR Wimalasiri]  R.Premadasa Stadium, Khettarama       28
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'New Zealand', 'deli...               0.91
#
#    meta.created  meta.revision  info.balls_per_over        info.city  \
#  0   2020-06-26              1                    6  Mount Maunganui
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2018-03-14]      female             T20                     399  ...
#
#    info.registry.people.SFM Devine  info.registry.people.SR Taylor  \
#  0                        de69af96                        92cf79a8
#
#     info.registry.people.SS Connell info.registry.people.SW Bates  \
#  0                         2f9a6bd1                      89bbc67a
#
#                     info.teams info.toss.decision info.toss.winner  \
#  0  [New Zealand, West Indies]              field      West Indies
#
#             info.umpires info.venue match_id
#  0  [BF Bowden, K Cross]   Bay Oval       29
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Pakistan', 'deliver...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-06-26              1                    6   Colombo  [2018-03-30]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     410  ...
#
#    info.registry.people.Sana Mir  info.registry.people.Sidra Ameen  \
#  0                      b287e7b1                          72c9ad99
#
#     info.registry.people.Susantha Dissanayake info.registry.people.WC Labrooy  \
#  0                                   7403e05b                        29d4e29b
#
#                info.teams info.toss.decision info.toss.winner  \
#  0  [Pakistan, Sri Lanka]                bat         Pakistan
#
#                      info.umpires                        info.venue match_id
#  0  [AG Dissanayake, PN Udawatta]  Nondescripts Cricket Club Ground       30
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'West Indies', 'deli...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-07-06              1                    6   Karachi  [2018-04-03]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     665  ...
#
#    info.registry.people.Shaheen Shah Afridi  info.registry.people.Shoaib Malik  \
#  0                                 45a7e761                           64c34cd0
#
#     info.registry.people.Shozab Raza info.registry.people.Usman Shinwari  \
#  0                          153c67dc                            f0e722e0
#
#                  info.teams info.toss.decision info.toss.winner  \
#  0  [West Indies, Pakistan]                bat      West Indies
#
#                info.umpires        info.venue match_id
#  0  [Aleem Dar, Ahsan Raza]  National Stadium       31
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'India', 'deliveries...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-07-06              1                    6    Dublin  [2018-06-27]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     678  ...
#
#    info.registry.people.Simi Singh  info.registry.people.V Kohli  \
#  0                        c9945bdf                      ba607b88
#
#     info.registry.people.WB Rankin info.registry.people.YS Chahal  \
#  0                        29b89ae8                       57ee1fde
#
#           info.teams info.toss.decision info.toss.winner  \
#  0  [India, Ireland]              field          Ireland
#
#               info.umpires             info.venue match_id
#  0  [M Hawthorne, R Black]  The Village, Malahide       32
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Zimbabwe', 'deliver...               0.91
#
#    meta.created  meta.revision  info.balls_per_over    info.dates info.gender  \
#  0   2020-07-06              1                    6  [2018-07-06]        male
#
#    info.match_type  info.match_type_number info.outcome.winner  ...  \
#  0             T20                     687           Australia  ...
#
#     info.registry.people.TJ Matibiri  info.registry.people.TK Musakanda  \
#  0                          4a3132b1                           9f9b903e
#
#    info.registry.people.TM Head info.registry.people.WP Masakadza  \
#  0                     12b610c2                          4bc0a378
#
#                info.teams info.toss.decision info.toss.winner  \
#  0  [Zimbabwe, Australia]                bat         Zimbabwe
#
#                 info.umpires          info.venue match_id
#  0  [RB Tiffin, TJ Matibiri]  Harare Sports Club       33
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'South Africa', 'del...               0.91
#
#    meta.created  meta.revision  info.balls_per_over    info.city    info.dates  \
#  0   2020-07-06              1                    6  East London  [2018-10-09]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     698  ...
#
#    info.registry.people.SC Williams  info.registry.people.T Shamsi  \
#  0                         afe57f7a                       a03bba42
#
#     info.registry.people.TK Musakanda info.registry.people.TS Chisoro  \
#  0                           9f9b903e                        4b2d6789
#
#                   info.teams info.toss.decision info.toss.winner  \
#  0  [South Africa, Zimbabwe]                bat     South Africa
#
#                 info.umpires    info.venue match_id
#  0  [AT Holdstock, S George]  Buffalo Park       34
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'South Africa', 'del...               0.91
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2020-01-12              1                    6  Johannesburg
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2019-02-03]        male             T20                     734  ...
#
#    info.registry.people.Shaheen Shah Afridi  info.registry.people.Shoaib Malik  \
#  0                                 45a7e761                           64c34cd0
#
#     info.registry.people.T Shamsi info.registry.people.Usman Shinwari  \
#  0                       a03bba42                            f0e722e0
#
#                   info.teams info.toss.decision info.toss.winner  \
#  0  [South Africa, Pakistan]              field         Pakistan
#
#                  info.umpires             info.venue match_id
#  0  [A Paleker, AT Holdstock]  The Wanderers Stadium       35
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Australia', 'delive...               0.91
#
#    meta.created  meta.revision  info.balls_per_over    info.dates info.gender  \
#  0   2020-07-06              1                    6  [2018-11-25]        male
#
#    info.match_type  info.match_type_number info.outcome.winner  ...  \
#  0             T20                     714               India  ...
#
#     info.registry.people.RR Pant  info.registry.people.S Dhawan  \
#  0                      919a3be2                       0a476045
#
#    info.registry.people.SD Fry info.registry.people.V Kohli  \
#  0                    6b725ed1                     ba607b88
#
#             info.teams info.toss.decision info.toss.winner  \
#  0  [Australia, India]                bat        Australia
#
#             info.umpires             info.venue match_id
#  0  [P Wilson, GA Abood]  Sydney Cricket Ground       36
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Bangladesh', 'deliv...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-07-06              1                    6  St Kitts  [2018-07-31]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     692  ...
#
#    info.registry.people.S Badree  info.registry.people.Shakib Al Hasan  \
#  0                      76388dc8                              7dc35884
#
#    info.registry.people.Soumya Sarkar  info.registry.people.Tamim Iqbal  \
#  0                           4d9f9686                          3b041a12
#
#                    info.teams info.toss.decision info.toss.winner  \
#  0  [Bangladesh, West Indies]              field      West Indies
#
#                   info.umpires               info.venue match_id
#  0  [JS Wilson, GO Brathwaite]  Warner Park, Basseterre       37
#
#  [1 rows x 50 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Bangladesh', 'deliv...               0.91
#
#    meta.created  meta.revision  info.balls_per_over   info.city    info.dates  \
#  0   2020-07-06              1                    6  Lauderhill  [2018-08-05]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                     694  ...
#
#    info.registry.people.Sabbir Rahman  info.registry.people.Shakib Al Hasan  \
#  0                           7147f314                              7dc35884
#
#    info.registry.people.Soumya Sarkar  info.registry.people.Tamim Iqbal  \
#  0                           4d9f9686                          3b041a12
#
#                    info.teams info.toss.decision info.toss.winner  \
#  0  [Bangladesh, West Indies]                bat       Bangladesh
#
#                  info.umpires  \
#  0  [N Duguid, GO Brathwaite]
#
#                                            info.venue match_id
#  0  Central Broward Regional Park Stadium Turf Ground       38
#
#  [1 rows x 51 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Uganda', 'deliverie...               0.91
#
#    meta.created  meta.revision  info.balls_per_over   info.city    info.dates  \
#  0   2020-06-29              1                    6  Amstelveen  [2018-07-07]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     444  ...
#
#    info.registry.people.RV Scholes  info.registry.people.S Kemigisha  \
#  0                        2dc78362                          05026222
#
#     info.registry.people.SJ Bryce info.registry.people.WPM van Liemt  \
#  0                       2ca65aee                           2bd48588
#
#             info.teams info.toss.decision info.toss.winner  \
#  0  [Uganda, Scotland]              field         Scotland
#
#              info.umpires  info.venue match_id
#  0  [CA Polosak, R Black]  VRA Ground       39
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Papua New Guinea', ...               0.91
#
#    meta.created  meta.revision  info.balls_per_over   info.city    info.dates  \
#  0   2020-06-29              1                    6  Amstelveen  [2018-07-07]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     446  ...
#
#    info.registry.people.T Ruma  info.registry.people.V Araa  \
#  0                    3697a0ff                     040f11e8
#
#     info.registry.people.V Frank info.registry.people.WPM van Liemt  \
#  0                      4f58d65d                           2bd48588
#
#                         info.teams info.toss.decision info.toss.winner  \
#  0  [Papua New Guinea, Bangladesh]              field       Bangladesh
#
#                    info.umpires  info.venue match_id
#  0  [CA Polosak, WPM van Liemt]  VRA Ground       40
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Scotland', 'deliver...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-06-29              1                    6   Utrecht  [2018-07-10]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     451  ...
#
#    info.registry.people.S Tippoch  info.registry.people.SJ Bryce  \
#  0                       9c4b58db                       2ca65aee
#
#     info.registry.people.W Liengprasert info.registry.people.WPM van Liemt  \
#  0                             4dabe716                           2bd48588
#
#               info.teams info.toss.decision info.toss.winner  \
#  0  [Scotland, Thailand]                bat         Scotland
#
#                    info.umpires                   info.venue match_id
#  0  [CA Polosak, WPM van Liemt]  Sportpark Maarschalkerweerd       41
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Uganda', 'deliverie...               0.91
#
#    meta.created  meta.revision  info.balls_per_over   info.city    info.dates  \
#  0   2020-06-29              1                    6  Amstelveen  [2018-07-10]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     452  ...
#
#    info.registry.people.R Ntono  info.registry.people.S Nampiina  \
#  0                     4b6da99c                         91d9aa26
#
#     info.registry.people.S Redfern info.registry.people.SM Kavanagh  \
#  0                        5b038989                         7e9b3b60
#
#            info.teams info.toss.decision info.toss.winner  \
#  0  [Uganda, Ireland]              field          Ireland
#
#                          info.umpires  info.venue match_id
#  0  [Ahmed Shah Pakteen, JM Williams]  VRA Ground       42
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'United Arab Emirate...               0.91
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2020-06-29              1                    6   Utrecht  [2018-07-10]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     453  ...
#
#    info.registry.people.Sanjida Islam  info.registry.people.Shamima Sultana  \
#  0                           12755a62                              724645f5
#
#     info.registry.people.UCKA Dona info.registry.people.WPM van Liemt  \
#  0                        caa99fcb                           2bd48588
#
#                             info.teams info.toss.decision info.toss.winner  \
#  0  [United Arab Emirates, Bangladesh]              field       Bangladesh
#
#                 info.umpires                   info.venue match_id
#  0  [R Black, WPM van Liemt]  Sportpark Maarschalkerweerd       43
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Ireland', 'deliveri...               0.91
#
#    meta.created  meta.revision  info.balls_per_over   info.city    info.dates  \
#  0   2020-06-29              1                    6  Amstelveen  [2018-07-12]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     455  ...
#
#    info.registry.people.SM Kavanagh  info.registry.people.T Ruma  \
#  0                         7e9b3b60                     3697a0ff
#
#     info.registry.people.V Araa info.registry.people.V Frank  \
#  0                     040f11e8                     4f58d65d
#
#                      info.teams info.toss.decision  info.toss.winner  \
#  0  [Ireland, Papua New Guinea]              field  Papua New Guinea
#
#                  info.umpires  info.venue match_id
#  0  [CA Polosak, JM Williams]  VRA Ground       44
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Thailand', 'deliver...               0.91
#
#    meta.created  meta.revision  info.balls_per_over   info.city    info.dates  \
#  0   2020-06-29              1                    6  Amstelveen  [2018-07-14]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                     461  ...
#
#    info.registry.people.S Saengsakaorat  info.registry.people.S Tippoch  \
#  0                             6214c0c6                        9c4b58db
#
#     info.registry.people.W Liengprasert info.registry.people.WPM van Liemt  \
#  0                             4dabe716                           2bd48588
#
#             info.teams info.toss.decision info.toss.winner  \
#  0  [Thailand, Uganda]              field           Uganda
#
#                 info.umpires  info.venue match_id
#  0  [R Black, WPM van Liemt]  VRA Ground       45
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Thailand', 'deliver...               0.91
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2020-06-30              1                    6  Kuala Lumpur
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2018-06-07]      female             T20                     426  ...
#
#    info.registry.people.Shamima Sultana  info.registry.people.V Kalidas  \
#  0                             724645f5                        42d76418
#
#     info.registry.people.W Liengprasert info.registry.people.WC Labrooy  \
#  0                             4dabe716                        29d4e29b
#
#                 info.teams info.toss.decision info.toss.winner  \
#  0  [Thailand, Bangladesh]              field       Bangladesh
#
#             info.umpires            info.venue match_id
#  0  [N Sivan, V Kalidas]  Kinrara Academy Oval       46
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Pakistan', 'deliver...               0.91
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2020-06-30              1                    6  Kuala Lumpur
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2018-06-09]      female             T20                     429  ...
#
#    info.registry.people.Sarika Prasad  info.registry.people.Sidra Nawaz  \
#  0                           8ff397fa                          ca3ded6f
#
#     info.registry.people.T Bhatia info.registry.people.V Krishnamurthy  \
#  0                       211dc1ce                             c3f21798
#
#            info.teams info.toss.decision info.toss.winner  \
#  0  [Pakistan, India]                bat         Pakistan
#
# ...
#  0  [Thailand, Singapore]         Thailand                bat
#
#                          info.umpires                         info.venue  \
#  0  [Aasif Iqbal, Gayathri Venugopal]  Royal Selangor Club, Kuala Lumpur
#
#    match_id
#  0      985
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Japan', 'deliveries...               0.92
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2024-02-13              1                    6  Kuala Lumpur
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2024-02-13]      female             T20                    1775  ...
#
#    info.registry.people.S Kotte  info.registry.people.Seika Sumi  \
#  0                     6c8904c8                         704b4c30
#
#     info.registry.people.Theertha Satish info.registry.people.Vaishnave Mahesh  \
#  0                              ee3dcb3f                              31c56f40
#
#                        info.teams info.toss.winner info.toss.decision  \
#  0  [Japan, United Arab Emirates]            Japan                bat
#
#                         info.umpires                        info.venue match_id
#  0  [Nur Hijrah, Ramasamy Venkatesh]  Selangor Turf Club, Kuala Lumpur      986
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Qatar', 'deliveries...               0.92
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2024-02-13              1                    6  Kuala Lumpur
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2024-02-13]      female             T20                    1776  ...
#
#    info.registry.people.Saleema Imtiaz  info.registry.people.T Kale  \
#  0                            d17d21d5                     bc9bd4c6
#
#     info.registry.people.V Bowen info.registry.people.Zahid Usman  \
#  0                      7297ac4d                         5ee3b5bd
#
#             info.teams info.toss.winner info.toss.decision  \
#  0  [Qatar, Indonesia]        Indonesia              field
#
#                      info.umpires                   info.venue match_id
#  0  [Saleema Imtiaz, Zahid Usman]  Bayuemas Oval, Kuala Lumpur      987
#
#  [1 rows x 48 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Nepal', 'deliveries...               0.92
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2024-02-13              1                    6     Bangi  [2024-02-13]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                    1777  ...
#
#    info.registry.people.Shamma Ali  info.registry.people.Shathira Jakir  \
#  0                        012bd3f6                             6b992a6f
#
#     info.registry.people.Shriya Kumari info.registry.people.Sumayya Abdul  \
#  0                            5e452781                           a521ba3e
#
#            info.teams info.toss.winner info.toss.decision  \
#  0  [Nepal, Maldives]            Nepal                bat
#
#                     info.umpires                   info.venue match_id
#  0  [L Poobalan, Shathira Jakir]  YSD-UKM Cricket Oval, Bangi      988
#
#  [1 rows x 47 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Hong Kong', 'delive...               0.92
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2024-02-14              1                    6  Kuala Lumpur
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2024-02-14]      female             T20                    1778  ...
#
#    info.registry.people.Shivani Mishra  info.registry.people.T Putthawong  \
#  0                            2982a0c7                           23e3f2d6
#
#     info.registry.people.V Bowen info.registry.people.Y Daswani  \
#  0                      7297ac4d                       2038a273
#
#                info.teams info.toss.winner info.toss.decision  \
#  0  [Hong Kong, Thailand]         Thailand              field
#
#                info.umpires                   info.venue match_id
#  0  [Aasif Iqbal, N Perera]  Bayuemas Oval, Kuala Lumpur      989
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'United Arab Emirate...               0.92
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2024-02-14              1                    6     Bangi  [2024-02-14]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                    1779  ...
#
#    info.registry.people.Saleema Imtiaz  info.registry.people.Shathira Jakir  \
#  0                            d17d21d5                             6b992a6f
#
#     info.registry.people.Theertha Satish info.registry.people.Vaishnave Mahesh  \
#  0                              ee3dcb3f                              31c56f40
#
#                            info.teams      info.toss.winner info.toss.decision  \
#  0  [United Arab Emirates, Indonesia]  United Arab Emirates                bat
#
#                         info.umpires                   info.venue match_id
#  0  [Saleema Imtiaz, Shathira Jakir]  YSD-UKM Cricket Oval, Bangi      990
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Malaysia', 'deliver...               0.92
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2024-02-14              1                    6  Kuala Lumpur
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2024-02-14]      female             T20                    1780  ...
#
#    info.registry.people.Siow Tzin Yee  info.registry.people.V Bowen  \
#  0                           686b7194                      7297ac4d
#
#     info.registry.people.WA Duraisingam info.registry.people.Wan Julia  \
#  0                             7467fe01                       bee0c85c
#
#            info.teams info.toss.winner info.toss.decision  \
#  0  [Malaysia, Japan]         Malaysia                bat
#
#                      info.umpires                   info.venue match_id
#  0  [Aasif Iqbal, Shivani Mishra]  Bayuemas Oval, Kuala Lumpur      991
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Kuwait', 'deliverie...               0.92
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2024-02-14              1                    6     Bangi  [2024-02-14]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0      female             T20                    1781  ...
#
#    info.registry.people.SR Magar  info.registry.people.Saleema Imtiaz  \
#  0                      61c22ad0                             d17d21d5
#
#    info.registry.people.Shathira Jakir  info.registry.people.Zeefa Jilani  \
#  0                            6b992a6f                           3f2b40f0
#
#          info.teams info.toss.winner info.toss.decision  \
#  0  [Kuwait, Nepal]           Kuwait                bat
#
#                     info.umpires                   info.venue match_id
#  0  [Nur Hijrah, Saleema Imtiaz]  YSD-UKM Cricket Oval, Bangi      992
#
#  [1 rows x 50 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'United Arab Emirate...               0.92
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2024-02-19              1                    6  Kuala Lumpur
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2024-02-16]      female             T20                    1782  ...
#
#    info.registry.people.T Putthawong  info.registry.people.Theertha Satish  \
#  0                          23e3f2d6                              ee3dcb3f
#
#     info.registry.people.V Bowen info.registry.people.Vaishnave Mahesh  \
#  0                      7297ac4d                              31c56f40
#
#                           info.teams      info.toss.winner info.toss.decision  \
#  0  [United Arab Emirates, Thailand]  United Arab Emirates                bat
#
#                         info.umpires                   info.venue match_id
#  0  [Gayathri Venugopal, Nur Hijrah]  Bayuemas Oval, Kuala Lumpur      993
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Nepal', 'deliveries...               0.92
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2024-02-19              1                    6  Kuala Lumpur
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2024-02-16]      female             T20                    1783  ...
#
#    info.registry.people.Siow Tzin Yee  info.registry.people.V Bowen  \
#  0                           686b7194                      7297ac4d
#
#     info.registry.people.WA Duraisingam info.registry.people.Wan Julia  \
#  0                             7467fe01                       bee0c85c
#
#            info.teams info.toss.winner info.toss.decision  \
#  0  [Nepal, Malaysia]            Nepal                bat
#
#                info.umpires                   info.venue match_id
#  0  [Aasif Iqbal, N Perera]  Bayuemas Oval, Kuala Lumpur      994
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'United Arab Emirate...               0.92
#
#    meta.created  meta.revision  info.balls_per_over     info.city  \
#  0   2024-02-19              1                    6  Kuala Lumpur
#
#       info.dates info.gender info.match_type  info.match_type_number  ...  \
#  0  [2024-02-18]      female             T20                    1784  ...
#
#    info.registry.people.Theertha Satish  info.registry.people.Vaishnave Mahesh  \
#  0                             ee3dcb3f                               31c56f40
#
#     info.registry.people.WA Duraisingam info.registry.people.Wan Julia  \
#  0                             7467fe01                       bee0c85c
#
#                           info.teams      info.toss.winner info.toss.decision  \
#  0  [United Arab Emirates, Malaysia]  United Arab Emirates                bat
#
#                       info.umpires                   info.venue match_id
#  0  [Gayathri Venugopal, N Perera]  Bayuemas Oval, Kuala Lumpur      995
#
#  [1 rows x 47 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Zimbabwe', 'deliver...               0.92
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2024-07-06              1                    6    Harare  [2024-07-06]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                    2737  ...
#
#    info.registry.people.TL Chatara  info.registry.people.W Madhevere  \
#  0                        5bbabe59                          a879b92c
#
#     info.registry.people.WP Masakadza info.registry.people.Washington Sundar  \
#  0                           4bc0a378                               f19ccfad
#
#            info.teams info.toss.winner info.toss.decision  \
#  0  [Zimbabwe, India]            India              field
#
#             info.umpires          info.venue match_id
#  0  [F Mutizwa, I Chabi]  Harare Sports Club      996
#
#  [1 rows x 50 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'India', 'deliveries...               0.92
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2024-07-08              1                    6    Harare  [2024-07-07]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                    2739  ...
#
#    info.registry.people.TL Chatara  info.registry.people.W Madhevere  \
#  0                        5bbabe59                          a879b92c
#
#     info.registry.people.WP Masakadza info.registry.people.Washington Sundar  \
#  0                           4bc0a378                               f19ccfad
#
#            info.teams info.toss.winner info.toss.decision  \
#  0  [India, Zimbabwe]            India                bat
#
#              info.umpires          info.venue match_id
#  0  [F Mutizwa, L Rusere]  Harare Sports Club      997
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'India', 'deliveries...               0.92
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2024-07-11              1                    6    Harare  [2024-07-10]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                    2749  ...
#
#    info.registry.people.W Madhevere  info.registry.people.WP Masakadza  \
#  0                         a879b92c                           4bc0a378
#
#     info.registry.people.Washington Sundar info.registry.people.YBK Jaiswal  \
#  0                                f19ccfad                         6c19c6e5
#
#            info.teams info.toss.winner info.toss.decision  \
#  0  [India, Zimbabwe]            India                bat
#
#             info.umpires          info.venue match_id
#  0  [L Rusere, P Sizara]  Harare Sports Club      998
#
#  [1 rows x 50 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'Zimbabwe', 'deliver...               0.92
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2024-07-24              1                    6    Harare  [2024-07-13]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                    2759  ...
#
#    info.registry.people.TU Deshpande  info.registry.people.W Madhevere  \
#  0                          46a9bea1                          a879b92c
#
#     info.registry.people.Washington Sundar info.registry.people.YBK Jaiswal  \
#  0                                f19ccfad                         6c19c6e5
#
#            info.teams info.toss.winner info.toss.decision  \
#  0  [Zimbabwe, India]            India              field
#
#             info.umpires          info.venue match_id
#  0  [F Mutizwa, I Chabi]  Harare Sports Club      999
#
#  [1 rows x 49 columns],
#                                               innings  meta.data_version  \
#  0  [{'1st innings': {'team': 'India', 'deliveries...               0.92
#
#    meta.created  meta.revision  info.balls_per_over info.city    info.dates  \
#  0   2024-07-24              1                    6    Harare  [2024-07-14]
#
#    info.gender info.match_type  info.match_type_number  ...  \
#  0        male             T20                    2762  ...
#
#    info.registry.people.TU Deshpande  info.registry.people.W Madhevere  \
#  0                          46a9bea1                          a879b92c
#
#     info.registry.people.Washington Sundar info.registry.people.YBK Jaiswal  \
#  0                                f19ccfad                         6c19c6e5
#
#            info.teams info.toss.winner info.toss.decision  \
#  0  [India, Zimbabwe]         Zimbabwe              field
#
#             info.umpires          info.venue match_id
#  0  [F Mutizwa, I Chabi]  Harare Sports Club     1000
#
#  [1 rows x 49 columns],
#  ...]

# %%
final_df[1]

# %%
final_df[1].shape
# Out:
# (1, 48)

# %%
final_df[1].balls_per_over
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5748\932599511.py in ?()
# ----> 1 final_df[1].balls_per_over
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'balls_per_over'

# %%
count=0
for val in final_df[1]:
    print(val)
    count+=1
    if count==4:
        break
# Out:
# innings
# meta.data_version
# meta.created
# meta.revision

# %%
final_df[1].match_id
# Out:
# 0    2
# Name: match_id, dtype: int64

# %%
count=0
for record in final_df:
    count+=1
    if count==record.match_id:
        print(record)
        print(".............")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5748\1100628544.py in ?()
#       1 count=0
#       2 for record in final_df:
#       3     count+=1
# ----> 4     if count==record.match_id:
#       5         print(record)
#       6         print(".............")
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
final_df[1].innings
# Out:
# 0    [{'1st innings': {'team': 'New Zealand', 'deli...
# Name: innings, dtype: object

# %%
final_df[1].columns
# Out:
# Index(['innings', 'meta.data_version', 'meta.created', 'meta.revision',
#        'info.balls_per_over', 'info.city', 'info.dates', 'info.gender',
#        'info.match_type', 'info.outcome.by.runs', 'info.outcome.winner',
#        'info.overs', 'info.player_of_match', 'info.players.Bangladesh',
#        'info.players.New Zealand', 'info.registry.people.AL Gillies',
#        'info.registry.people.BC Broad', 'info.registry.people.BM Wheeler',
#        'info.registry.people.C Munro', 'info.registry.people.C de Grandhomme',
#        'info.registry.people.CJ Anderson', 'info.registry.people.CM Brown',
#        'info.registry.people.IS Sodhi', 'info.registry.people.Imrul Kayes',
#        'info.registry.people.JDS Neesham',
#        'info.registry.people.KS Williamson', 'info.registry.people.MJ Santner',
#        'info.registry.people.Mahmudullah',
#        'info.registry.people.Mashrafe Mortaza',
#        'info.registry.people.Mosaddek Hossain',
#        'info.registry.people.Nurul Hasan',
#        'info.registry.people.Rubel Hossain', 'info.registry.people.SB Haig',
#        'info.registry.people.Sabbir Rahman',
#        'info.registry.people.Shakib Al Hasan',
#        'info.registry.people.Soumya Sarkar',
#        'info.registry.people.TA Blundell', 'info.registry.people.TA Boult',
#        'info.registry.people.TC Bruce', 'info.registry.people.Tamim Iqbal',
#        'info.registry.people.Taskin Ahmed', 'info.registry.people.WR Knights',
#        'info.teams', 'info.toss.decision', 'info.toss.winner', 'info.umpires',
#        'info.venue', 'match_id'],
#       dtype='object')

# %%
final_df[1].info
# Out:
# <bound method DataFrame.info of                                              innings  meta.data_version  \
# 0  [{'1st innings': {'team': 'New Zealand', 'deli...               0.91
#
#   meta.created  meta.revision  info.balls_per_over        info.city  \
# 0   2017-01-08              2                    6  Mount Maunganui
#
#      info.dates info.gender info.match_type  info.outcome.by.runs  ...  \
# 0  [2017-01-08]        male             T20                    27  ...
#
#   info.registry.people.TC Bruce  info.registry.people.Tamim Iqbal  \
# 0                      f92c9151                          3b041a12
#
#   info.registry.people.Taskin Ahmed info.registry.people.WR Knights  \
# 0                          ef18b66e                        63cbf8d8
#
#                   info.teams info.toss.decision info.toss.winner  \
# 0  [New Zealand, Bangladesh]              field       Bangladesh
#
#              info.umpires info.venue match_id
# 0  [CM Brown, WR Knights]   Bay Oval        2
#
# [1 rows x 48 columns]>
