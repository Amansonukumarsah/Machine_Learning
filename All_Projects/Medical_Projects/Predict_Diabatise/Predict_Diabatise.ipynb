# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df_copy = df.copy(deep=True)
df_copy[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI']] = df_copy[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.NaN)

# %%
df_copy
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0           72.0           35.0      NaN  33.6
# 1            1.0     85.0           66.0           29.0      NaN  26.6
# 2            8.0    183.0           64.0            NaN      NaN  23.3
# 3            1.0     89.0           66.0           23.0     94.0  28.1
# 4            NaN    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0    101.0           76.0           48.0    180.0  32.9
# 764          2.0    122.0           70.0           27.0      NaN  36.8
# 765          5.0    121.0           72.0           23.0    112.0  26.2
# 766          1.0    126.0           60.0            NaN      NaN  30.1
# 767          1.0     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df_copy.isnull().sum()
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# histogram is representation of data distribution

# %%
df_vis = df_copy.hist(figsize=(20,20),bins=20)
for ax in df_vis.flatten():
    ax.set_title(ax.get_title(),fontsize=16)
    ax.set_xlabel("Frequency",fontsize=14)
    ax.set_ylabel("Number_Of_People",fontsize=14)
plt.tight_layout()
plt.show()

# %%
df_copy['Pregnancies'].skew()
# Out:
# 0.8855351681761828

# %%
# if the value of range is 0.5 to -0.5 then we considered that value as sysmetrical or we can replace their null value with their mean
df_copy['Glucose'].skew()
# Out:
# 0.5309885349396285

# %%
df['Glucose'].plot(kind='box',figsize=(6,6))
# it have zero outliers
# Out:
# <Axes: >

# %%
# it is sysmetrical distribution of data
df_copy['BloodPressure'].skew()
# Out:
# 0.13415273171959252

# %%
sns.kdeplot(df_copy,x='BloodPressure',fill=True,color='blue')
            # sns.displot(data=df_copy, x='BloodPressure', height=6, aspect=1)
# Out:
# C:\Users\amank\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='BloodPressure', ylabel='Density'>

# %%
# checking the outliers it contain the outliers and if the outliers is present then we have to remove that outliers
df_copy['BloodPressure'].plot(kind='box',figsize=(6,6))
# Out:
# <Axes: >

# %%
sns.scatterplot(x=df.index, y=df['BloodPressure'], color='blue')
# Out:
# <Axes: ylabel='BloodPressure'>

# %%
df_copy['SkinThickness'].skew()
# Out:
# 0.690619013984192

# %%
df_copy['SkinThickness'].plot(kind='box',figsize=(6,6))
# Out:
# <Axes: >

# %%
sns.kdeplot(df_copy,x='SkinThickness',fill=True,color='blue')
# Out:
# C:\Users\amank\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='SkinThickness', ylabel='Density'>

# %%
df_copy['Pregnancies'].fillna(df_copy['Pregnancies'].mean(),inplace = True)
df_copy['Glucose'].fillna(df_copy['Glucose'].mean(),inplace=True)
df_copy['BloodPressure'].fillna(df_copy['BloodPressure'].median(),inplace=True)
df_copy['SkinThickness'].fillna(df_copy['SkinThickness'].median(),inplace=True)
df_copy['Insulin'].fillna(df_copy['Insulin'].median(),inplace=True)
df_copy['BMI'].fillna(df_copy['BMI'].median(),inplace=True)

# %%
df_vis = df_copy.hist(figsize=(20,20),bins=20)
for ax in df_vis.flatten():
    ax.set_title(ax.get_title(),fontsize=16)
    ax.set_xlabel("Frequency",fontsize=14)
    ax.set_ylabel("Number_Of_People",fontsize=14)
plt.tight_layout()
plt.show()

# %%
df_vis
# Out:
# array([[<Axes: title={'center': 'Pregnancies'}, xlabel='Frequency', ylabel='Number_Of_People'>,
#         <Axes: title={'center': 'Glucose'}, xlabel='Frequency', ylabel='Number_Of_People'>,
#         <Axes: title={'center': 'BloodPressure'}, xlabel='Frequency', ylabel='Number_Of_People'>],
#        [<Axes: title={'center': 'SkinThickness'}, xlabel='Frequency', ylabel='Number_Of_People'>,
#         <Axes: title={'center': 'Insulin'}, xlabel='Frequency', ylabel='Number_Of_People'>,
#         <Axes: title={'center': 'BMI'}, xlabel='Frequency', ylabel='Number_Of_People'>],
#        [<Axes: title={'center': 'DiabetesPedigreeFunction'}, xlabel='Frequency', ylabel='Number_Of_People'>,
#         <Axes: title={'center': 'Age'}, xlabel='Frequency', ylabel='Number_Of_People'>,
#         <Axes: title={'center': 'Outcome'}, xlabel='Frequency', ylabel='Number_Of_People'>]],
#       dtype=object)
