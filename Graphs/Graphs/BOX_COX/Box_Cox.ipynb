# %%
#BOX_COX

# %%
print("BOX_COX")
# Out:
# BOX_COX

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import PowerTransformer

# %%
df = pd.read_csv('C:/Users/amank/OneDrive/Documents/MACHINE_LEARNING_ALL_MATERIALS/concrete_data.csv')

# %%
df.head()
# Out:
#    cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    coarse_aggregate  fine_aggregate   age  concrete_compressive_strength
# 0            1040.0            676.0   28                          79.99
# 1            1055.0            676.0   28                          61.89
# 2             932.0            594.0  270                          40.27
# 3             932.0            594.0  365                          41.05
# 4             978.4            825.5  360                          44.30

# %%
df.shape
# Out:
# (1030, 9)

# %%
df.isnull().sum()
# Out:
# cement                           0
# blast_furnace_slag               0
# fly_ash                          0
# water                            0
# superplasticizer                 0
# coarse_aggregate                 0
# fine_aggregate                   0
# age                              0
# concrete_compressive_strength    0
# dtype: int64

# %%
df.describe()
# Out:
#             cement  blast_furnace_slag      fly_ash        water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        superplasticizer  coarse_aggregate  fine_aggregate           age  \
# count       1030.000000       1030.000000      1030.000000  1030.000000
# mean           6.204660        972.918932       773.580485    45.662136
# std            5.973841         77.753954        80.175980    63.169912
# min            0.000000        801.000000       594.000000     1.000000
# ...

# %%
x=df.drop(columns=['concrete_compressive_strength'])
y=df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#Applying LinearRegression without using transformation
lr=LinearRegression()
lr.fit(x_train,y_train)

y_pred = lr.predict(x_test)
r2_score(y_test,y_pred)
# Out:
# 0.6275531792314851

# %%
#cross checking with cross val score

lr=LinearRegression()
np.mean(cross_val_score(lr,x,y,scoring='r2'))
# Out:
# 0.46099404916628633

# %%
#plotting the distplots without any transformtion

for col in x_train.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.distplot(x_train[col])
    # sns.kdeplot(x_train[col])
    plt.title(col)

    
    plt.subplot(122)
    stats.probplot(x_train[col],dist="norm",plot=plt)
    plt.title(col)
    plt.show()
# Out:
# C:\Users\amank\AppData\Local\Temp\ipykernel_12264\426814313.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[col])
# C:\Users\amank\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\amank\AppData\Local\Temp\ipykernel_12264\426814313.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %%
#Applyign Box-Cox Transform

plt = PowerTransformer(method="box-cox")
x_train_transformed=plt.fit_transform(x_train+0.000001)
x_test_transforms=plt.transform(x_test+0.000001)

pd.DataFrame({'cols':x_train.columns,'box_cox_lambdas':plt.lambdas_})
# Out:
#                  cols  box_cox_lambdas
# 0              cement         0.177025
# 1  blast_furnace_slag         0.025093
# 2             fly_ash        -0.038970
# 3               water         0.772682
# 4    superplasticizer         0.098811
# 5    coarse_aggregate         1.129813
# 6     fine_aggregate          1.782019
# 7                 age         0.066631

# %%
#Applying linaer Regression on transfomred data

lr=LinearRegression()
lr.fit(x_train_transformed,y_train)
y_pred2=lr.predict(x_train_transformed)
r2_score(y_test,y_pred2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 6
#       4 lr.fit(x_train_transformed,y_train)
#       5 y_pred2=lr.predict(x_train_transformed)
# ----> 6 r2_score(y_test,y_pred2)
#
# File ~\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:911, in r2_score(y_true, y_pred, sample_weight, multioutput, force_finite)
#     784 def r2_score(
#     785     y_true,
#     786     y_pred,
#    (...)
#     790     force_finite=True,
#     791 ):
#     792     """:math:`R^2` (coefficient of determination) regression score function.
#     793
#     794     Best possible score is 1.0 and it can be negative (because the
#    (...)
#     909     -inf
#     910     """
# --> 911     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     912         y_true, y_pred, multioutput
#     913     )
# ...

# %%
#using cross val score

pt=PowerTransformer(method='box-cox')
x_transformed=pt.fit_transform(x+0.0000001)

lr=LinearRegression()
np.mean(cross_val_score(lr,x_transformed,y,scoring='r2'))
# Out:
# 0.6658537942219861

# %%
#Before and After comparision for Box-Cox plot

for col in x_train_transformed.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.distplot(x_train[col])
    plt.title(col)

    plt.subplot(122)
    sns.distplot(x_train_transfoormed[col])
    plt.title(col)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 3
#       1 #Before and After comparision for Box-Cox plot
# ----> 3 for col in x_train_transformed.columns:
#       4     plt.figure(figsize=(14,4))
#       5     plt.subplot(121)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'
