# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]],columns=['cgpa','profile_score','lpa'])

# %%
df.head()
# Out:
#    cgpa  profile_score  lpa
# 0     8              8    4
# 1     7              9    5
# 2     6             10    6
# 3     5             12    7

# %%
def initialize_parameters(layer_dims):
    np.random.seed(3)
    parameters={}
    L = len(layer_dims)
    for i in range(1,L):
        parameters['w'+str(i)] = np.ones((layer_dims[i-1],layer_dims[i]))*0.1
        parameters['b'+str(i)] = np.zeros((layer_dims[i],1))
    return parameters

# %%
print(initialize_parameters([2,2,2]))
# Out:
# {'w1': array([[0.1, 0.1],
#        [0.1, 0.1]]), 'b1': array([[0.],
#        [0.]]), 'w2': array([[0.1, 0.1],
#        [0.1, 0.1]]), 'b2': array([[0.],
#        [0.]])}

# %%
def linear_forward(A_Prev,w,b):
    z = np.dot(w.T,A_Prev)+b
    return z

# %%
# forward propagation
def L_layer_forward(x,parameters):
    A = x
    L = len(parameters)//2  # number of layers in neural network
    for i in range(1,L+1):
        A_Prev = A
        w1 = parameters['w'+str(i)]
        b1 = parameters['b'+str(i)]

        A = linear_forward(A_Prev,w1,b1)

    return A,A_Prev

# %%
x = df[['cgpa','profile_score']].values[0].reshape(2,1)  # shape(no of feature,no of training example)
y= df[['lpa']].values[0][0]
parameters = initialize_parameters([2,2,1])

# %%
parameters
# Out:
# {'w1': array([[0.1, 0.1],
#         [0.1, 0.1]]),
#  'b1': array([[0.],
#         [0.]]),
#  'w2': array([[0.1],
#         [0.1]]),
#  'b2': array([[0.]])}

# %%
L_layer_forward(x,parameters)
# Out:
# (array([[0.32]]),
#  array([[1.6],
#         [1.6]]))

# %%
# now update the paramerts after calculation of loss

# %%
def update_parameters(parameters,y,y_hat,A1,x):
    parameters['w2'][0][0] = parameters['w2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
    parameters['w2'][1][0] = parameters['w2'][1][0] + (0.001*2*(y-y_hat)*A1[1][0])
    parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001*2*(y-y_hat))

    parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
    parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
    parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])

    parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
    parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
    parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])

# %%
# epochs implementation

parameters = initialize_parameters([2,2,1])

epochs = 5

for i in range(epochs):
    loss = []
    for j in range(df.shape[0]):
        x= df[['cgpa','profile_score']].values[j].reshape(2,1)
        y = df[['lpa']].values[j][0]
        # parameters initialization
        y_hat,A1 = L_layer_forward(x,parameters)
        y_hat = y_hat[0]
        update_parameters(parameters,y,y_hat,A1,x)
        loss.append((y-y_hat)**2)
parameters
# Out:
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][0][0] = parameters['w2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][1][0] = parameters['w2'][1][0] + (0.001*2*(y-y_hat)*A1[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001*2*(y-y_hat))
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][0][0] = parameters['w2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][1][0] = parameters['w2'][1][0] + (0.001*2*(y-y_hat)*A1[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001*2*(y-y_hat))
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][0][0] = parameters['w2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][1][0] = parameters['w2'][1][0] + (0.001*2*(y-y_hat)*A1[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001*2*(y-y_hat))
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][0][0] = parameters['w2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][1][0] = parameters['w2'][1][0] + (0.001*2*(y-y_hat)*A1[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001*2*(y-y_hat))
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][0][0] = parameters['w2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][1][0] = parameters['w2'][1][0] + (0.001*2*(y-y_hat)*A1[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001*2*(y-y_hat))
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][0][0] = parameters['w2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][1][0] = parameters['w2'][1][0] + (0.001*2*(y-y_hat)*A1[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001*2*(y-y_hat))
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][0][0] = parameters['w2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][1][0] = parameters['w2'][1][0] + (0.001*2*(y-y_hat)*A1[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001*2*(y-y_hat))
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][0][0] = parameters['w2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][1][0] = parameters['w2'][1][0] + (0.001*2*(y-y_hat)*A1[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001*2*(y-y_hat))
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][0][0] = parameters['w2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][1][0] = parameters['w2'][1][0] + (0.001*2*(y-y_hat)*A1[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001*2*(y-y_hat))
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][0][0] = parameters['w2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][1][0] = parameters['w2'][1][0] + (0.001*2*(y-y_hat)*A1[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001*2*(y-y_hat))
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][0][0] = parameters['w2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][1][0] = parameters['w2'][1][0] + (0.001*2*(y-y_hat)*A1[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001*2*(y-y_hat))
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][0][0] = parameters['w2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][1][0] = parameters['w2'][1][0] + (0.001*2*(y-y_hat)*A1[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001*2*(y-y_hat))
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][0][0] = parameters['w2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][1][0] = parameters['w2'][1][0] + (0.001*2*(y-y_hat)*A1[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001*2*(y-y_hat))
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][0][0] = parameters['w2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][1][0] = parameters['w2'][1][0] + (0.001*2*(y-y_hat)*A1[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001*2*(y-y_hat))
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
# ...
#   parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][0][0] = parameters['w2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][1][0] = parameters['w2'][1][0] + (0.001*2*(y-y_hat)*A1[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001*2*(y-y_hat))
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][0][0] = parameters['w2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][1][0] = parameters['w2'][1][0] + (0.001*2*(y-y_hat)*A1[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001*2*(y-y_hat))
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][0][0] = parameters['w2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][1][0] = parameters['w2'][1][0] + (0.001*2*(y-y_hat)*A1[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001*2*(y-y_hat))
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][0][0] = parameters['w2'][0][0] + (0.001*2*(y-y_hat)*A1[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w2'][1][0] = parameters['w2'][1][0] + (0.001*2*(y-y_hat)*A1[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b2'][0][0] = parameters['b2'][0][0] + (0.001*2*(y-y_hat))
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][0] = parameters['w1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][0][1] = parameters['w1'][0][1] + (0.001*2*(y-y_hat)*parameters['w2'][0][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][0][0] = parameters['b1'][0][0] + (0.001*2*(y-y_hat)*parameters['w2'][0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][0] = parameters['w1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[0][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['w1'][1][1] = parameters['w1'][1][1] + (0.001*2*(y-y_hat)*parameters['w2'][1][0]*x[1][0])
# C:\Users\amank\AppData\Local\Temp\ipykernel_12744\5685432.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   parameters['b1'][1][0] = parameters['b1'][1][0] + (0.001*2*(y-y_hat)*parameters['w2'][1][0])
# {'w1': array([[0.273603  , 0.3993222 ],
#         [0.28787155, 0.42586102]]),
#  'b1': array([[0.02885522],
#         [0.03133223]]),
#  'w2': array([[0.42574893],
#         [0.50219328]]),
#  'b2': array([[0.11841278]])}
