# %%
import seaborn as sns
import pandas as pd

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic = pd.read_csv('train.csv')

# %%
flights = sns.load_dataset('flights')

# %%
flights.head
# Out:
# <bound method NDFrame.head of      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]>

# %%
tips.head
# Out:
# <bound method NDFrame.head of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
iris = sns.load_dataset('iris')

# %% [markdown]
# 1. Scatterplot (Numerical - Numerical)

# %%
sns.scatterplot(x='total_bill', y='tip', hue='sex', style='smoker', size='size', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
#  Lineplot (Numerical - Numerical)

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
new = flights.groupby('year').sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 new = flights.groupby('year').sum().reset_index()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:3063, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3058 else:
#    3059     # If we are grouping on categoricals we want unobserved categories to
#    3060     # return zero, rather than the default of NaN which the reindexing in
#    3061     # _agg_general() returns. GH #31422
#    3062     with com.temp_setattr(self, "observed", True):
# -> 3063         result = self._agg_general(
#    3064             numeric_only=numeric_only,
#    3065             min_count=min_count,
#    3066             alias="sum",
#    3067             npfunc=np.sum,
#    3068         )
#    3070     return self._reindex_output(result, fill_value=0)
#
# ...

# %%
sns.lineplot(new['year'],new['passengers'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 sns.lineplot(new['year'],new['passengers'])
#
# NameError: name 'new' is not defined

# %% [markdown]
# Bar Plot (Numerical - Categorical)

# %%
sns.barplot(x='Pclass',y='Age',hue='Sex',data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# 3. Box Plot (Numerical - Categorical)

# %%
sns.boxplot(x='Sex',y='Age',hue='Survived',data=titanic)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# 4. Distplot (Numerical - Categorical)

# %%
sns.kdeplot(data=titanic[titanic['Survived'] == 0]['Age'], label='Not Survived', shade=False)
sns.kdeplot(data=titanic[titanic['Survived'] == 1]['Age'], label='Survived', shade=False)
# Out:
# C:\Users\amank\AppData\Local\Temp\ipykernel_3928\1775385698.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=titanic[titanic['Survived'] == 0]['Age'], label='Not Survived', shade=False)
# C:\Users\amank\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\amank\AppData\Local\Temp\ipykernel_3928\1775385698.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=titanic[titanic['Survived'] == 1]['Age'], label='Survived', shade=False)
# ...

# %% [markdown]
# 5. HeatMap (Categorical - Categorical)

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>
